# %% [markdown]
# # TBSS Analysis Procedures

# %% [markdown]
# ## DTI Preprocessing
#
# main.sh
#
# Inspect all subjects for model fit

# %% [markdown]
# Move FA results from DTI preprocessing to new tbss directory

# %%
for sub_dir in /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/dtiprep/*/
do
  cp "$sub_dir"*FA.nii.gz /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/
  #find $sub_dir -type f | echo `grep -i *FA.nii.gz` #| cp {} /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss
done

# %% [markdown]
# Move MD to new tbss directory and will need to rename as FA so that later steps work. Do not get these mixed up with the actual FA data!

# %%
for sub_dir in /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/dtiprep/*/
do
  cp "$sub_dir"*MD.nii.gz /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/MD/
  #find $sub_dir -type f | echo `grep -i *FA.nii.gz` #| cp {} /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss
done

# %%
for file in `ls /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/MD/`
do
  partic=`echo "$file" | cut -c5-9`
  echo $partic
  mv "$file" "sub-${partic}_dti_FA.nii.gz"
done

# %% [markdown]
# ## TBSS

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1
ls
# Out:
# sub-40160_dti_FA.nii.gz sub-40623_dti_FA.nii.gz sub-40750_dti_FA.nii.gz
# sub-40170_dti_FA.nii.gz sub-40629_dti_FA.nii.gz sub-40758_dti_FA.nii.gz
# sub-40288_dti_FA.nii.gz sub-40638_dti_FA.nii.gz sub-40768_dti_FA.nii.gz
# sub-40351_dti_FA.nii.gz sub-40649_dti_FA.nii.gz sub-40769_dti_FA.nii.gz
# sub-40490_dti_FA.nii.gz sub-40650_dti_FA.nii.gz sub-40773_dti_FA.nii.gz
# sub-40496_dti_FA.nii.gz sub-40653_dti_FA.nii.gz sub-40775_dti_FA.nii.gz
# sub-40512_dti_FA.nii.gz sub-40655_dti_FA.nii.gz sub-40777_dti_FA.nii.gz
# sub-40519_dti_FA.nii.gz sub-40656_dti_FA.nii.gz sub-40778_dti_FA.nii.gz
# sub-40520_dti_FA.nii.gz sub-40658_dti_FA.nii.gz sub-40779_dti_FA.nii.gz
# sub-40522_dti_FA.nii.gz sub-40664_dti_FA.nii.gz sub-40782_dti_FA.nii.gz
# sub-40524_dti_FA.nii.gz sub-40665_dti_FA.nii.gz sub-40784_dti_FA.nii.gz
# sub-40547_dti_FA.nii.gz sub-40668_dti_FA.nii.gz sub-40796_dti_FA.nii.gz
# sub-40550_dti_FA.nii.gz sub-40672_dti_FA.nii.gz sub-40803_dti_FA.nii.gz
# sub-40564_dti_FA.nii.gz sub-40685_dti_FA.nii.gz sub-40811_dti_FA.nii.gz
# sub-40601_dti_FA.nii.gz sub-40694_dti_FA.nii.gz sub-40861_dti_FA.nii.gz
# sub-40608_dti_FA.nii.gz sub-40720_dti_FA.nii.gz sub-40876_dti_FA.nii.gz
# sub-40615_dti_FA.nii.gz sub-40728_dti_FA.nii.gz sub-40878_dti_FA.nii.gz
# sub-40619_dti_FA.nii.gz sub-40738_dti_FA.nii.gz

# %%
tbss_1_preproc *FA.nii.gz
# Out:
# processing sub-40160_dti_FA
# processing sub-40170_dti_FA
# processing sub-40288_dti_FA
# processing sub-40351_dti_FA
# processing sub-40490_dti_FA
# processing sub-40496_dti_FA
# processing sub-40512_dti_FA
# processing sub-40519_dti_FA
# processing sub-40520_dti_FA
# processing sub-40522_dti_FA
# processing sub-40524_dti_FA
# processing sub-40547_dti_FA
# processing sub-40550_dti_FA
# processing sub-40564_dti_FA
# processing sub-40601_dti_FA
# processing sub-40608_dti_FA
# processing sub-40615_dti_FA
# processing sub-40619_dti_FA
# processing sub-40623_dti_FA
# processing sub-40629_dti_FA
# processing sub-40638_dti_FA
# processing sub-40649_dti_FA
# processing sub-40650_dti_FA
# processing sub-40653_dti_FA
# processing sub-40655_dti_FA
# processing sub-40656_dti_FA
# processing sub-40658_dti_FA
# processing sub-40664_dti_FA
# processing sub-40665_dti_FA
# processing sub-40668_dti_FA
# processing sub-40672_dti_FA
# processing sub-40685_dti_FA
# processing sub-40694_dti_FA
# processing sub-40720_dti_FA
# processing sub-40728_dti_FA
# processing sub-40738_dti_FA
# processing sub-40750_dti_FA
# processing sub-40758_dti_FA
# processing sub-40768_dti_FA
# processing sub-40769_dti_FA
# processing sub-40773_dti_FA
# processing sub-40775_dti_FA
# processing sub-40777_dti_FA
# processing sub-40778_dti_FA
# processing sub-40779_dti_FA
# processing sub-40782_dti_FA
# processing sub-40784_dti_FA
# processing sub-40796_dti_FA
# processing sub-40803_dti_FA
# processing sub-40811_dti_FA
# processing sub-40861_dti_FA
# processing sub-40876_dti_FA
# processing sub-40878_dti_FA
# Now running "slicesdir" to generate report of all input images
# Finished. To view, point your web browser at
# file:/Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/FA/slicesdir/index.html

# %%
open -a "Google Chrome" /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/FA/slicesdir/index.html

# %%
#tbss_2_reg -T
tbss_2_reg -n
# Out:
# sub-40160_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40160_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40170_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40288_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40351_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40490_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40496_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40512_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40519_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40520_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40522_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40524_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40547_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40550_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40564_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40601_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40608_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40615_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40619_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40623_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40629_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40638_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40649_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40649_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40649_dti_FA_FA
# ...
# sub-40878_dti_FA_FA_to_sub-40782_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40784_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40796_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40803_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40811_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40861_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40876_dti_FA_FA
# sub-40160_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40170_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40288_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40351_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40490_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40496_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40512_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40519_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40520_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40522_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40524_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40547_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40550_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40564_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40601_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40608_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40615_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40619_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40623_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40629_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40638_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40649_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40650_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40653_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40655_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40656_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40658_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40664_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40665_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40668_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40672_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40685_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40694_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40720_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40728_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40738_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40750_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40758_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40768_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40769_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40773_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40775_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40777_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40778_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40779_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40782_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40784_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40796_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40803_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40811_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40861_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40876_dti_FA_FA_to_sub-40878_dti_FA_FA
# sub-40878_dti_FA_FA_to_sub-40878_dti_FA_FA

# %%
tbss_3_postreg -S

# %%
cd stats
fsleyes all_FA -b 0,0.8 mean_FA_skeleton -b 0.2,0.8 -l Green &

# %% [markdown]
# Restricting mean_FA_mask values to values between 0.2 and 1, since the mask output from tbss_3_postreg covers more than the white matter. This will reduce the area used in permutation testing with TFCE and increase the power of our analysis.

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/stats
fslmaths mean_FA -thr 0.2 -uthr 1 -bin mean_FA_mask_thr.nii.gz

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/stats
fslmaths mean_FA -thr 0.22 -uthr 1 -bin mean_FA_mask_thr22.nii.gz

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_young_1/stats
fslmaths mean_FA -thr 0.2 -uthr 1 -bin mean_FA_mask_thr.nii.gz

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_young_1/stats
fslmaths mean_FA -thr 0.22 -uthr 1 -bin mean_FA_mask_thr22.nii.gz

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/stats
tbss_4_prestats 0.22 #replace 0.2 if need to change it
# Out:
# /usr/local/fsl/bin/tbss_4_prestats: line 89: cd: stats: No such file or directory
# creating skeleton mask using threshold 0.22
# creating skeleton distancemap (for use in projection search)
# projecting all FA data onto skeleton
#
# now run stats - for example:
# randomise -i all_FA_skeletonised -o tbss -m mean_FA_skeleton_mask -d design.mat -t design.con -n 500 --T2 -V
# (after generating design.mat and design.con)

# %%
cd ../stats

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### Steps:
# 1. Create design matrices and contrasts in Excel, then copy and paste into .txt files
# 2. Use Text2Vest to reformat for tbss

# %% [markdown]
# #### Create design matrices and contrasts for each age group independently in Excel, then copy and paste into .txt files
# Excel tip: absolute cell reference shortcut is cmd + t on mac
#
# Design matrix = \[ actalph-AVERAGE(actalph) \]
#
# Contrasts = \[0 1\], \[0,-1\]
#
# Save contrasts to .txt file in tbss directory

# %% [markdown]
# #### Use Text2Vest to reformat for tbss

# %%
#Older adults

cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/stats

Text2Vest design_age_alpha.txt design_age_alpha.mat
Text2Vest design_age_CR.txt design_age_CR.con
# Out:
# ll
# ls
# ll
# ls
# if
# then
# else
# elif
# fi
# case
# esac
# for
# select
# while
# until
# do
# done
# in
# function
# time
# {
# }
# !
# [[
# ]]
# display
# shell_session_delete_expired
# shell_session_history_allowed
# shell_session_history_check
# shell_session_history_enable
# shell_session_save
# shell_session_save_history
# shell_session_update
# update_terminal_cwd
# .
# :
# [
# alias
# bg
# bind
# break
# builtin
# caller
# cd
# command
# compgen
# complete
# continue
# declare
# dirs
# disown
# echo
# enable
# eval
# exec
# exit
# export
# false
# fc
# fg
# getopts
# hash
# help
# history
# jobs
# kill
# let
# local
# logout
# popd
# printf
# pushd
# pwd
# read
# readonly
# return
# set
# shift
# shopt
# source
# suspend
# test
# times
# trap
# true
# type
# typeset
# ulimit
# umask
# unalias
# unset
# wait
# ppmtouil
# pip3.7
# lzmainfo
# xwdtopnm
# ppmtorgb3
# pamtohdiff
# pbmtoppa
# pyenv
# ccmake
# ppmtoyuvsplit
# pbmtonokia
# dot2gxl
# leaftoppm
# smtpd2.7.py
# Rscript
# fmriprep-docker
# pnminvert
# pkg-config
# pbmpage
# sos-runner
# pnmrotate
# bdftogd
# idle2.7
# pgmslice
# nib-diff
# ppmshadow
# anytopnm
# asciitopgm
# ppmtoppm
# pgmkernel
# tifftopnm
# c++-9
# pbmtoescp2
# ppmcie
# x86_64-apple-darwin19-gcc-9
# ddbugtopbm
# pgmhist
# rawtoppm
# webpng
# pnmcut
# pnmhistmap
# palmtopnm
# pamseq
# nipy_tsdiffana
# fitstopnm
# pampick
# tctmttest
# pngtopam
# idle
# ppmmix
# wget
# heudiconv_monitor
# pnmtofits
# pamrecolor
# pgmmake
# markdown_py
# jupyter-run
# pbmtog3
# cluster
# pbmtomrf
# pamtilt
# spython
# pbmtodjvurle
# tchtest
# gv2gml
# dipy_track_det
# dipy_fit_dti
# xzdec
# tiffsplit
# pambayer
# gxl2dot
# ppmforge
# pnmtosgi
# ppmtojpeg
# wheel3
# mtvtoppm
# pamstretch
# python2-config
# pigz
# fax2tiff
# tred
# pamfunc
# prov-compare
# pcdovtoppm
# git-receive-pack
# pnmnoraw
# docker
# fc-list
# gcov-tool-9
# pnmpaste
# pamsharpness
# pyenv-install
# unflatten
# ppmtoilbm
# texi2pdf
# 2to3-2.7
# jupyter-nbextension
# lispmtopgm
# gtester
# ppmrainbow
# pbmtopgm
# pnmtops
# pbmtocis
# autoscan
# notary
# gd2togif
# docker-machine
# 411toppm
# pip2
# gcc-ranlib-9
# gfortran
# mm2gv
# 2to3
# pbmtoxbm
# hyperkit
# ppmfade
# pamperspective
# python3
# pnmtoddif
# wish8.6
# tcfmgr
# png-fix-itxt
# dot
# pamslice
# pamsharpmap
# ppmtotga
# pbmtowbmp
# pgmenhance
# apm
# heudiconv
# jbigtopnm
# pgmtosbig
# fieldmap_intendedfor.py
# cmake
# ppmflash
# tiffdump
# pamaddnoise
# g++-9
# pytest
# pbmtogem
# ppmspread
# ppmddumpfont
# gitk
# easy_install
# fc-pattern
# ilbmtoppm
# pbmtox10bm
# pnmfile
# pydoc
# dipy_fit_csa
# python
# python2
# unxz
# ppmdmkfont
# tcbmgr
# pythonw
# pbmtolps
# tiff2bw
# gfortran-4.2
# pammasksharpen
# jiv
# atom
# freetype-config
# pip3
# pgmnorm
# sed
# sunicontopnm
# gdbus-codegen
# fc-validate
# pamtopdbimg
# cjpeg
# autom4te
# ipython
# ppmchange
# nib-dicomfs
# escp2topbm
# jpegtran
# gvpack
# pbmminkowski
# libpng16-config
# yuvtoppm
# xzegrep
# gsettings
# gv2gxl
# VBoxManage
# pngfix
# python3.7-config
# zeisstopnm
# python2.7-config
# dipy_fit_dki
# glib-compile-schemas
# webpmux
# pamscale
# pgmtopgm
# fc-query
# tiffcmp
# pnmtopng
# cameratopam
# pnmtojpeg
# yuvsplittoppm
# rasttopnm
# ppmtopjxl
# tiff2pdf
# pbmtoicon
# pbmreduce
# ppmdist
# jupyter-notebook
# pamsistoaglyph
# twopi
# dipy_median_otsu
# pbmtozinc
# unlzma
# pgmtexture
# pbmto4425
# ppmdim
# pbmpscale
# ppmtopuzz
# ybmtopbm
# pbmtomgr
# pbmtopi3
# hdifftopam
# pamexec
# ppmtowinicon
# easy_install-3.7
# diffimg
# pktopbm
# pgmtolispm
# fiascotopnm
# pamdepth
# VBoxHeadless
# prov-convert
# pnmarith
# pyenv-uninstall
# pjtoppm
# pyvenv-3.7
# xzfgrep
# pasteurize
# sirtopnm
# nipy_4dto3d
# webpinfo
# tcumttest
# gdtopng
# libpng-config
# pnmscalefixed
# gdbm_dump
# pbmtomda
# git-credential-netrc
# pod2texi
# isympy
# graphml2gv
# pamtompfont
# gobject-query
# brushtopbm
# kubectl.docker
# nipy_3dto4d
# pnmsmooth
# pnmenlarge
# brew
# pnmtopclxl
# fstopgm
# pgmdeshadow
# ppmtopi1
# ppmdcfont
# BIDS_conversion_R33.sh
# bmptopnm
# pnminterp
# g3topbm
# pbmtoascii
# pnmcrop
# pnmtopalm
# R
# pamsplit
# idle2
# tcucodec
# pbmlife
# pamundice
# xpmtoppm
# rletopnm
# pngtogd2
# csv2rdf
# sgitopnm
# pbmtoepsi
# wheel
# sldtoppm
# patchwork
# tclsh8.6
# tctmgr
# pnmflip
# eyuvtoppm
# pydoc2.7
# powerpc-apple-darwin8-gfortran-4.2
# x86_64-apple-darwin19-gcc-ranlib-9
# nipy_4d_realign
# autoupdate
# pnmtosir
# sccmap
# pambackground
# manweb
# i686-apple-darwin8-gfortran-4.2
# pdbimgtopam
# jpeg2ktopam
# pnmtotiff
# pamshadedrelief
# python3.7m
# git-upload-archive
# smtpd2.py
# mdatopbm
# ppmtoeyuv
# ppmntsc
# djpeg
# gfortran-uninstall
# picttoppm
# dipy_nlmeans
# giftopnm
# pythonw2.7
# pnmindex
# pnmshear
# pnmtile
# annotate
# pamtopnm
# pamunlookup
# tiffcrop
# neotoppm
# wbmptopbm
# pbmtobbnbg
# nib-trk2tck
# gvmap
# pamrgbatopng
# rlatopam
# nib-ls
# python3.7m-config
# pgmramp
# pnmcomp
# pamtooctaveimg
# gio-querymodules
# docker-credential-osxkeychain
# pamtohtmltbl
# ppmtoneo
# ppmtosixel
# pnmtorast
# pnmhisteq
# gemtopbm
# flea
# idle3
# gdcmpgif
# gapplication
# python3.7
# dipy_fit_mapmri
# xz
# ppmdither
# tchmgr
# pi1toppm
# pampaintspill
# spctoppm
# VirtualBox
# pbmtomatrixorbital
# gdparttopng
# mgrtopbm
# ximtoppm
# glib-compile-resources
# chardetect
# pamtogif
# ppmtoacad
# vboxwebsrv
# tchmttest
# cpp-9
# parrec2nii
# pamdice
# macptopbm
# pamtosvg
# pbmtogo
# VBoxDTrace
# neato
# ppmtolj
# ppmtoxpm
# img2webp
# texindex
# pamstretch-gen
# pbmmask
# python-config
# ppmglobe
# tiffdither
# sputoppm
# x86_64-apple-darwin19-gcc-nm-9
# cmuwmtopbm
# htop
# rdfgraphisomorphism
# pngtopnm
# dipy_mask
# pamstereogram
# python3-config
# info
# ipython3
# tiffset
# pip
# pamflip
# pfmtopam
# avstopam
# tgatoppm
# giftogd2
# pbmtextps
# ppmpat
# pamtoxvmini
# hpcdtoppm
# pynets
# pi3topbm
# python-build
# pbmtoepson
# pnmnorm
# ppmtobmp
# tiff2ps
# pynets_run.py
# pnmtoxwd
# futurize
# pamcrater
# osage
# qrttoppm
# ppmtoarbtxt
# gcov-dump-9
# ppm3d
# neurodocker
# pamcomp
# cmake-gui
# lzless
# rdf2dot
# cistopbm
# pamedge
# gvgen
# easy_install-2.7
# pbmtoatk
# x86_64-apple-darwin19-gcc-ar-9
# ppmtoterm
# vbox-img
# tiffinfo
# pythonw2
# docker-credential-desktop
# jupyter-nbconvert
# ppmdraw
# pnmconvol
# pgmoil
# gresource
# bioradtopgm
# jsonschema
# psidtopgm
# tcfmttest
# pamtopfm
# dipy_info
# pamtojpeg2k
# smime_keys
# pamwipeout
# pamsummcol
# jpegtopnm
# glibtool
# gcc-nm-9
# hipstopgm
# BIDS_conversion_ADM.sh
# ppmtopict
# tqdm
# gfortran-4.0
# pnmcat
# pgmminkowski
# gvpr
# rdfpipe
# gtester-report
# nop
# pc1toppm
# pgmabel
# atktopbm
# ppmtogif
# pbmclean
# glibtoolize
# ppmrelief
# ctest
# jupyter-troubleshoot
# pamfixtrunc
# xzless
# pal2rgb
# dipy_fit_csd
# tcbmttest
# VBoxBalloonCtrl
# lzcmp
# pnmstitch
# circo
# gd2topng
# ppmtoicr
# pygmentize
# xzcat
# mrftopbm
# gxl2gv
# xcpengine-singularity
# jupyter-migrate
# pamthreshold
# autoreconf
# pamstack
# VBoxAutostart
# pgpring
# pbmtocmuwm
# nipypecli
# dipy_reslice
# wrjpgcom
# pnmtofiasco
# gfortran-9
# fv_export_local-itadmin.sh
# nitool
# pydoc3.7
# ppmquant
# autoconf
# texi2dvi
# pbmtoplot
# pbmmake
# pnmtotiffcmyk
# pamtoavs
# pbmtosunicon
# pamsumm
# pnmpsnr
# vpnkit
# ppmtopgm
# acyclic
# pbmtopk
# gml2gv
# gdlib-config
# tabulate
# pgmbentley
# autoheader
# pamendian
# imginfo
# rawtopgm
# pcretest
# VBoxBugReport
# glib-gettextize
# xzcmp
# pamtofits
# gouldtoppm
# unpigz
# dcmstack
# lzcat
# bidsify
# pnmtorle
# pamoil
# pbmtoibm23xx
# git-credential-osxkeychain
# sfdp
# gc
# xcpengine-docker
# pgmmedian
# gcov-9
# 2to3-2
# python2.7
# pammixinterlace
# pbmtopsg3
# gcc-ar-9
# fc-cache
# ppmtopj
# pampop9
# idle3.7
# pnmremap
# gdbus
# pcxtoppm
# fc-cat
# pdftexi2dvi
# pydeface.py
# ppmtospu
# git-cvsserver
# ppmcolors
# ppmtoleaf
# infokey
# lzdiff
# nipy_diagnose
# pgmtost4
# dijkstra
# pip2.7
# pnmtopnm
# pgmedge
# pamvalidate
# gdbmtool
# sbigtopgm
# jupyter-console
# tcbtest
# pamtotiff
# tcutest
# glib-genmarshal
# pcre-config
# nib-tck2trk
# pyvenv
# ppmhist
# tcttest
# dot_builtins
# prune
# winicontoppm
# git-shell
# pgmmorphconv
# pamlookup
# dwebp
# xbmtopbm
# plasma_store
# nib-nifti-dx
# ppmtoyuv
# ppmtomap
# pgmcrater
# ifnames
# pnmalias
# pnmcolormap
# pgmtopbm
# mutt
# texi2any
# pbmto10x
# ppmtopcx
# gd2copypal
# ppmrough
# ppmmake
# jupyter-serverextension
# lzmadec
# iptest3
# fax2ps
# pnmmercator
# node
# rgb3toppm
# fc-match
# pnmgamma
# infotopam
# lzgrep
# docker-compose
# pnmtoplainpnm
# x86_64-apple-darwin19-c++-9
# pamdeinterlace
# gcc-9
# pamgradient
# pnmsplit
# tiffcp
# fdp
# tcatest
# lzmore
# xvminitoppm
# git-upload-pack
# jupyter-trust
# pamfile
# pnmnlfilt
# pamtouil
# pamtodjvurle
# sqlite3_analyzer
# pgmtofs
# pngtogd
# pnmmargin
# bcomps
# pamchannel
# pnmquantall
# pbmtomacp
# pbmtext
# tcamgr
# pnmpad
# ppmwheel
# msmtp
# ppmlabel
# thinkjettopbm
# pnmquant
# pbmupc
# runxlrd.py
# sos
# kubectl
# x86_64-apple-darwin19-gcc-9.2.0
# winicontopam
# pamtosrf
# pamditherbw
# pbmtoptx
# pgmnoise
# pbmtolj
# lzfgrep
# pamarith
# npx
# pgpewrap
# ccomps
# fc-conflist
# 2to3-3.7
# glib-mkenums
# jupyter-qtconsole
# xzmore
# pnmdepth
# pammosaicknit
# ppmquantall
# cwebp
# tiffmedian
# ppmshift
# yuy2topam
# pamenlarge
# xzgrep
# pamgauss
# pydoc3
# jupyter-kernelspec
# pamtotga
# pbmtoln03
# pstopnm
# ppmtompeg
# rdfs2dot
# jupyter-kernel
# jupyter
# jupyter-bundlerextension
# edgepaint
# x86_64-apple-darwin19-g++-9
# svgtopam
# pbr
# lzma
# iptest
# gdbm_load
# pamcut
# tcamttest
# jasper
# gemtopnm
# pbmtoybm
# x86_64-apple-darwin19-gfortran-9
# spottopgm
# pamfix
# st4topgm
# smtpd.py
# npm
# srftopam
# py.test
# pnmmontage
# git-subtree
# rdjpgcom
# ppmbrighten
# icontopbm
# lzegrep
# git
# cpack
# muttbug
# raw2tiff
# ppmtoapplevol
# pgmtoppm
# ppm2tiff
# makeinfo
# xzdiff
# gvcolor
# imgcmp
# pcregrep
# tcftest
# tiff2rgba
# pamtopam
# pamrubber
# pamtowinicon
# ppmtoascii
# dcm2niix
# ppmtv
# ppmtomitsu
# imgtoppm
# gio
# pamtopng
# ppmnorm
# ppmcolormask
# pnmscale
# fc-scan
# pydoc2
# VBoxVRDP
# bmptoppm
# pnmtojbig
# install-info
# mri_transform
# label_area
# kvlUpsampleMesh
# mri_ca_normalize
# mris_spherical_average
# fs_spmreg.glnxa64
# mris_divide_parcellation
# morph_subject-lh
# mris_sample_parc
# gca_read_test
# nmovie
# register.csh
# histo_register_block
# bbmask
# compute_label_volumes.csh
# test_tutorials.sh
# mri_segstats
# mri_ms_LDA
# usbtree
# gcam_labelterm_copydeltas_test_cuda
# mri_ca_label
# fsutils.py
# segment_subject_old_skull_strip
# mri_xvolavg
# dmri_group
# mri2nc
# mri_make_density_map
# mri_deface
# mri_create_tests
# mris_deform
# sfa2fieldsign
# qdec
# optseq2
# mri_relabel_nonwm_hypos
# mri_label_vals
# mri_pretess
# mris_distance_transform
# mris_transform
# fix_subject
# gcam_jacobterm_test_cuda
# mri_convert.bin
# kvlQuantifyHippocampalSubfieldSegmentations.sh
# label_border
# mri_robust_template
# mri_surfcluster.bin
# check_subject
# make_average_subcort
# freeview
# mris_compute_layer_intensities
# misc.py
# mris_hausdorff_dist
# tkmedit
# gcam_labelterm_test_cuda
# meanval
# kvlTestHippocampalSubfields.sh
# UpdateNeeded
# mri_paint
# polyorder
# mri_fit_bias
# mri_copy_params
# mri_segment
# rebuild_gca_atlas.csh
# applyMorph
# mri_apply_bias
# morph_subject
# tal_compare
# make_upright
# grad_unwarp
# mri_interpolate
# mri_compute_distances
# cblumwmgyri
# remove_talairach
# mri_ms_EM_with_atlas
# bbregister
# mris_register_to_label
# mri_gcab_train
# make_average_volume
# mriVoxInLabelPartialVolumeTest
# mris_average_curvature
# fs_update
# mris_intensity_profile
# mris_volume
# morph_only_subject-lh
# mri_segstats_cuda
# mris_sample_label
# mris_mesh_subdivide.bin
# mri_segreg
# sratio
# browse-minc-header.tcl
# oct_train
# mris_fwhm
# qdec_glmfit
# mris_ca_train
# mri_ca_register_cuda
# gcam_jacobenergy_test
# kvlSetReferencePosition
# morph_subject_on_seychelles
# hiam_make_template
# findsession
# mri_estimate_tissue_parms
# mri_wmfilter
# inflate_subject3
# mris_register
# flirt.fsl
# segmentSF_T1_long.sh
# mkxsubjreg
# mri_parselabel
# mri_aseg_edit_train
# mri_compute_layer_fractions
# mris_map_cuts
# createMorph
# spm_t_to_b
# renormalize_subject
# mris_classify_thickness
# dmrirc.example
# mris_flatten
# mris_svm_classify
# nmovie_qt
# mri_motion_correct.fsl
# gcam_removesingularities_test
# mris_add_template
# gcainit
# kvlCorrectLeftSideLabelsToRightSideLabels
# run_segmentSubjectT1T2_autoEstimateAlveusML.sh
# mri_make_labels
# t4imgs_4dfp
# map_central_sulcus
# xmlToHtml
# mri_gca_ambiguous
# mris_errors
# kvlOptimizePositionsWithICM
# run_SegmentSubject.sh
# fix_subject_corrected
# mris_anatomical_stats
# mris_volmask_vtk.bin
# kvlEvaluateQuantitativelyWithHausdorffDistance
# surf2vol
# gifti_test
# fsl_rigid_register
# dmri_paths
# bmedits2surf
# mri_seghead
# xsanatreg
# mri_probedicom
# gauss_4dfp
# labels_disjoint
# reg-mni305.2mm
# mri_extract_label
# kvlCalculatePositionCost
# conv1d_test_cuda
# mri_fdr
# unpacksdcmdir.tcl
# mri_fieldsign
# minc2seqinfo
# segmentSF_T2.sh
# labels_union
# mris2rgb
# mri_extract_largest_CC
# mrisp_paint
# kvlScaleMeshCollection
# mri_binarize
# dmri_trk2trk
# mris_apply_reg
# mri_compute_change_map
# long_create_base_sigma
# kvlSetHardCodedLocations.sh
# mris_volmask
# gcam_labelterm_copydeltas_test
# mri_fwhm
# mris_transmantle_dysplasia_paths
# mri_fcili
# wfilemask
# oct_rf_train
# mris_morph_stats
# mri_voldiff
# tcl_setup
# mkcontrast2m.glnxa64
# mri_motion_correct
# Spline3_test
# mni152reg
# mri_cvs_data_copy
# mri_volsynth
# gcam_cmp_test_cuda
# sphere_subject-rh
# mpr2mni305
# tksurferfv
# mris_BA_segment
# convgaussian_test_cuda
# mri_rigid_register
# mri_mark_temporal_lobe
# mri_partial_ribbon
# kvlRegister
# gcam_applygradient_test
# mris_flatten_cuda
# unpackimadir2
# gca-apply
# mris_seg2annot
# mri_polv
# mris_make_surfaces
# mkheadsurf
# mri_add_xform_to_header
# mri_matrix_multiply
# mri_aseg_edit_reclassify
# ico_supersample
# mri_topologycorrection
# mris_init_global_tractography
# mri_edit_wm_with_aseg
# kvlEMSegment
# mri_relabel_hypointensities
# segmentBS.sh
# cudadetect.bin
# gcam_smoothnessenergy_test
# kvlCombineManualSegmentationProtocols
# gcam_lle_test
# slicedelay
# mris_w_to_curv
# jkgcatrain
# mri_wbc
# tridec
# mris_compute_parc_overlap
# mri_fuse_intensity_images
# long_qdec_table
# kvlSegmentHippocampalSubfields.sh
# cp-dicom
# mri_rf_long_train
# fsfget.tcl
# bet.fsl
# mri-sph2surf
# mri_align_long.csh
# mri_label_volume
# morph_only_subject
# mri_mcsim
# mri_divide_segmentation
# cor_to_minc
# brec
# long_submit_jobs
# mris_remove_variance
# mri_mask
# long_stats_combine
# label_subject_flash
# mris_thickness_comparison
# kvlCropImage
# mris_warp
# mris_convert
# mris_remove_intersection
# mri_make_uchar
# mris_distance_map
# mris_merge_parcellations
# convgaussian_test
# pctsurfcon
# make_folding_atlas
# mri-funcvits
# compute_interrater_variability.csh
# mri_label2vol
# biasfield
# mri_gradient_info
# kvlCrop
# mri_build_priors
# mri_nu_correct.mni
# mri_head
# mris_curvature_stats
# mri_remove_neck
# makevol
# histo_synthesize
# clear_fs_env.csh
# mri_ms_fitparms
# mri_fslmat_to_lta
# label_elderly_subject
# mris_surface_to_vol_distances
# gcam_undogradient_test_cuda
# mris_distance_to_label
# mris_label_mode
# morph_tables-lh
# vol2symsurf
# mris_aseg_distance
# dmri_mergepaths
# kvlAddMeshToMeshCollection
# cuda_setup
# 3dvolreg.afni
# mri_convert_mdh
# mri_simulate_atrophy
# mri_concatenate_lta.bin
# gcam_labelterm_postantconsist_test
# mri_compute_bias
# kvlChangeKOfMeshCollection
# swi_process
# mri_extract_conditions
# inflate_subject_new
# mris_talairach
# mkmnc_index.tcl
# fsl_label2voxel
# groupstatsdiff
# defect-seg
# mris_pmake
# fsdcmdecompress
# gtmseg
# fast_selxavg3b.glnxa64
# meanfilter_test
# longHippoSubfieldsT1.sh
# tkmeditfv
# mris_surface_change
# print_unique_labels.csh
# mri_strip_nonwhite
# mri_multiscale_segment
# mris_label_area
# mri_watershed
# mksubjdirs
# mri_apply_inu_correction
# fslmaths.fsl
# mri_compute_structure_transforms
# xcerebralseg
# mri_fuse_segmentations
# mri_rf_train
# mri_info
# stat_normalize
# mri_multispectral_segment
# mri_morphology
# label_subject
# register_subject
# orientLAS
# mri_ribbon
# template
# aparcstatsdiff
# histo_fix_topology
# mri_compute_volume_intensities
# gcam_addstatus_test
# reinflate_subject-rh
# mris_inflate_cuda
# unpack_mnc.tcl
# mri_probe_ima
# unpackmincdir
# mri_make_bem_surfaces
# irepifitvol
# kvlCalculateAtlasMeshCollectionTotalCost
# mris_extract_main_component
# freesurfer
# help_xml_validate
# fslorient.fsl
# dsh
# mri_vol2roi
# dcmunpack
# wm-anat-snr
# flip_4dfp
# mri_parse_sdcmdir
# mri_map_cpdat
# regdat2xfm
# mri_synthesize
# morph_rgb-rh
# gcam_applygradient_test_cuda
# mris_svm_train
# fix_subject_corrected-lh
# make_symmetric
# mri_normalize
# mri_path2label
# mri_surf2vol
# mri_classify
# gcam_labelterm_postantconsist_test_cuda
# mri_motion_correct2
# cudadetect
# dmri_spline
# tal_QC_AZS
# register_subject_mixed
# gcam_labelterm_final_test_cuda
# gcam_clear_test_cuda
# mri_mergelabels
# mris_twoclass
# annot2std
# segment_monkey
# gcam_labelterm_mainloop_test_cuda
# mri_threshold
# segpons
# predict_v1.sh
# dmri_tensoreig
# register_elderly_subject
# spmregister
# mri_tessellate
# segment_subject_talmgh
# map_to_base
# map_all_labels-lh
# mri_reorient_LR.csh
# talairach_mgh
# bugr
# mri_concat.bin
# dicom-rename
# gcamCompare
# kvlAverageMeshes
# inflate_subject-rh
# mri_surfacemask
# mri_make_template
# mri_nl_align_binary
# mris_info
# fix_subject-rh
# gcam_smoothgradient_test_cuda
# analyzeto4dfp
# gcam_labelterm_removeoutliers_test_cuda
# kww_setup
# fsPrintHelp
# mris_make_map_surfaces
# mris_calc
# mri_jacobian
# exportGcam
# mri_binarize.bin
# mris_rf_label
# gcatrain
# mris_interpolate_warp
# mris_ms_refine
# inflate_subject_new-lh
# mri_sbbr
# mri_compute_overlap
# mri_elastic_energy
# conv1d_test
# list_otl_labels
# segment_subject_sc
# mris_annot_to_segmentation
# fix_subject_on_seychelles
# mri_transform_to_COR
# kvlAugmentManualSegmentationWithAutomatedSegmentation
# mris_curvature
# run_segmentSubjectT1_autoEstimateAlveusML.sh
# mris_left_right_register
# mris_fix_topology
# vertexvol
# mris_resample
# mris_rescale
# mri_label_accuracy
# vtk_setup
# rtview
# mri_add_new_tp
# mri_gtmpvc
# mri_vol2surf
# label2patch
# mris_decimate
# mri_robust_register.bin
# mri_annotation2label
# brec.awk
# kvlAddBorder
# epidewarp.fsl
# mri_rf_label
# fixup_mni_paths
# label_subject_mixed
# fs_tutorial_data
# mris_jacobian
# mri_extract
# lta_diff
# surfreg
# unpacksdcmdir
# lpcregister
# mri_gtmseg
# vsm-smooth
# spherical_stats
# mri_ca_tissue_parms
# talairach_afd
# vol2segavg
# mri_seg_diff
# dcmdrle.fs
# make_cortex_label
# mris_ms_surface_CNR
# trac-preproc
# tkregisterfv
# gcam_smoothnessterm_test
# dcmdir-info-mgh
# mris_topo_fixer
# gcam_jacobenergy_test_cuda
# map_all_labels
# fsfget
# fsr-checkxopts
# merge_stats_tables
# segment_subject_notal2
# kvlMathematicalMorphology
# deface_subject
# gcam_labelterm_test
# mri_glmfit
# mri_auto_fill
# mris_diff
# fslswapdim.fsl
# gcam_labelterm_final_test
# kvlColorCodeProbabilityImages
# mri_edit_segmentation
# get_label_thickness
# tractstats2table
# mri_rf_long_label
# mri_surf2surf
# mri_vol2vol_cuda
# mris_sphere
# sphere_subject-lh
# mri_evaluate_morph
# renormalize_T1_subject
# gcatrainskull
# fname2ext
# gcam_llterm_test_cuda
# avi2talxfm
# make_average_subject
# rbbr
# mris_ca_deform
# mri_gcut
# mri_mc
# asegstatsdiff
# kvlResample
# label2flat
# getfullpath
# mri_create_t2combined
# kvlAutoCrop
# fname2stem
# mris_make_face_parcellation
# fs_lib_check
# qdec.bin
# mri_ms_EM
# mri_vol2label
# mri_bc_sc_bias_correct
# mris_thickness_diff
# mri_twoclass
# mri_reduce
# bblabel
# thickdiffmap
# tkregister2
# mris_remove_negative_vertices
# isnifti
# mris_find_flat_regions
# gcam_smoothgradient_test
# datastruct_utils.py
# mris_niters2fwhm
# mri_train
# IsLTA
# inflate_subject
# fvcompare
# mris_parcellate_connectivity
# morph_subject-rh
# kvlApplyTransform
# setlabelstat
# apas2aseg
# kvlMapDeformationField
# recon-all
# mri_volcluster
# gcam_smoothnessenergy_test_cuda
# mri_em_register_cuda
# mri_cvs_check
# gcam_jacobterm_test
# mri_ca_register
# mri_concatenate_lta
# test_recon-all.csh
# mris_make_template
# mris_surface_stats
# mris_show
# mris_translate_annotation
# gcam_removestatus_test_cuda
# histo_compute_joint_density
# aseg2feat
# mris_congeal
# make_average_surface
# mri_segment_tumor
# mri_label_histo
# t4img_4dfp
# run_SegmentSubfieldsT1Longitudinal.sh
# wmsaseg
# tetgen
# xhemi-tal
# mris_smooth
# mri_dct_align
# mri_hausdorff_dist
# kvlMaskImage
# register_subject_flash
# mri_ibmc
# fscalc
# kvlQuantifyPosteriorProbabilityImages
# make_hemi_mask
# mris_rf_train
# fsl_sub_mgh
# mksurfatlas
# mri_distance_transform
# ms_refine_subject
# mris_refine_surfaces
# gcam_removestatus_test
# mri_cht2p
# mri_histo_normalize
# mri_linear_register
# gcam_llterm_test
# gcam_labelenergy_test_cuda
# stim_polar
# gcam_cmp_test
# reconbatchjobs
# progressbar.tcl
# mris_inflate
# rcbf-prep
# kvlConvert
# long_mris_slopes
# mri_joint_density
# mri_glmfit-sim
# bedpostx_mgh
# mris_register_to_volume
# mri_log_likelihood
# dcmdjpeg.fs
# rmcr
# dmri_motion
# gcam_labelenergy_test
# dmri_vox2vox
# unpack_ima.tcl
# mri_convert
# feat2surf
# lta_convert
# unpack_ima1.tcl
# register_child
# mri_diff
# show_tal
# mkfsdist
# gcam_labelterm_mainloop_test
# labels_intersect
# build_desikan_killiany_gcs.csh
# hiam_make_surfaces
# kvlUpsample
# reregister_subject_mixed
# mris_fix_topology_cuda
# mri_make_register
# mri_compute_seg_overlap
# mris_wm_volume
# mergeseg
# talairach
# gcam_clear_test
# mri_average
# connectgraph
# morph_only_subject-rh
# mri_linear_align_binary
# extract_talairach_avi_QA.awk
# mri_glmfit.bin
# recon-all.makefile
# mri_modify
# is-surface
# mriVoxInLabelPartialVolumeTest_cuda
# mkima_index.tcl
# dmri_forrest
# mris_segment_vals
# slicetimer.fsl
# mri_compute_volume_fractions
# mri_long_normalize
# gcam_lle_test_cuda
# make-segvol-table
# mri_robust_register
# gcam_write_test_cuda
# mris_fill
# imgreg_4dfp
# mri_label2label.bin
# kvlSegmentWithoutGUI
# gcam_write_test
# mri_stats2seg
# mri_compile_edits
# mri_hires_register
# gcam_removesingularities_test_cuda
# reinflate_subject-lh
# mris_preproc
# mris_longitudinal_surfaces
# mris_shrinkwrap
# mri_nl_align
# fs_time
# reg-feat2anat
# stem2fname
# gcaprepone
# reinflate_subject
# mri_cvs_register
# beta2sxa
# mris_thickness
# mri_mosaic
# vno_match_check
# fsman
# gcam_undogradient_test
# gdcmconv.fs
# fix_subject_corrected-rh
# ifh2hdr
# mri_concat
# morph_rgb-lh
# segmentSF_T1T2.sh
# 4dfptoanalyze
# mri_surfcluster
# asegstats2table
# mris_reverse
# kvlChangePointParametersOfMeshCollection
# qt_setup
# mri_apply_autoencoder
# groupstats
# gcam_smoothnessterm_test_cuda
# mri_xcorr
# segmentSF_T1.sh
# mri_register
# mris_compute_acorr
# quantifyBrainstemStructures.sh
# kvlBinaryThresholdImage
# mri_ca_train
# plot_structure_stats.tcl
# compute_vox2vox
# mris_volmask_vtk
# mris_compute_lgi
# mris_mesh_subdivide
# irepifitvol.glnx64
# spmmat2register
# fscalc.fsl
# mri_z2p
# mris_entropy
# long_create_orig
# xhemireg
# kvlCompressImage
# inflate_subject-lh
# mris_volsmooth
# mris_segmentation_stats
# mri_label2label
# mris_density
# mris_average_parcellation
# fix_subject-lh
# mris_register_label_map
# mris_exvivo_surfaces
# talairach2
# kvlReduceNumberOfIntensityLevels
# subject_info.py
# talairach_avi
# reg2subject
# mris_nudge
# sphere_subject
# fshelp
# mri_validate_skull_stripped
# mri_copy_values
# inflate_subject_new-rh
# aparc2feat
# run-qdec-glm
# oct_register_mosaic
# volume_copy_test_cuda
# xcorr
# trac-paths
# kvlMapLabelsOfAtlasMesh
# tksurfer
# skip_long_make_checks
# kvlSamplePositionsFromMeshCollection
# mris_simulate_atrophy
# run_mris_preproc
# mris_label2annot
# mri_train_autoencoder
# hiam_register
# mris_volmask_novtk
# mris_expand
# kvlEvaluateQuantitatively
# mris_euler_number
# mri_normalize_tp2
# mri_cc
# mri-func2sph
# mriMarkLabelBorderVoxelTest
# talsegprob
# mri_nlfilter
# mri_vol2vol.bin
# rbftest
# mri_cal_normalize
# dt_recon
# isanalyze
# mri_warp_convert
# parc_atlas_jackknife_test
# unpackimadir
# mris_roiCircle
# aparcstats2table
# mri_mask.bin
# mris_label_calc
# mri_vol2vol
# mri_cnr
# inflate_subject_sc
# mris_copy_header
# mris_AA_shrinkwrap
# mcparams2reg
# mris_segment
# meanfilter_test_cuda
# mri_aparc2aseg
# gifti_tool
# mris_compute_optimal_kernel
# feat2segstats
# renormalize_subject_keep_editting
# LongQdecTable.py
# mris_sphere_cuda
# kvlOverwriteEmptySlices
# mris_compute_overlap
# mriMarkLabelBorderVoxelTest_cuda
# mri_fill
# mri_histo_eq
# segment_subject_notal
# mri_concatenate_gcam
# petsc_setup
# mri_and
# wmedits2surf
# segment_subject
# mris_make_average_surface
# gcam_addstatus_test_cuda
# long_stats_tps
# label_child
# trac-all
# mris_fbirn_annot
# mris_rotate
# mri_edit_segmentation_with_surfaces
# fsl.5.0.2.xyztrans.sch
# run_segmentSubjectT2_autoEstimateAlveusML.sh
# mri_dct_align_binary
# mri_aparc2wmseg
# kvlSmoothMesh
# zero_lt_4dfp
# morph_tables-rh
# fsr-getxopts
# quantifyHippocampalSubfields.sh
# mri_cal_renormalize_gca
# kvlMergeMeshCollections
# mri_brain_volume
# swi_preprocess
# mris_mef_surfaces
# mri_cor2label
# histo_segment
# long_stats_slopes
# stattablediff
# mris_ca_label
# dmri_pathstats
# fslregister
# mri_strip_subject_info
# kvlAddProbabilityImages
# mris_compute_volume_fractions
# dmri_train
# mri_em_register
# xfmrot
# mris_multiscale_stats
# mri_segment_wm_damage
# mri_gdfglm
# mri_update_gca
# mri_linear_align
# kvlRasterizeAtlasMesh
# long_submit_postproc
# gcam_labelterm_removeoutliers_test
# mri_correct_segmentations
# repair_siemens_file
# dmrirc.long.example
# fsgd_parser.py
# mri_or
# check_siemens_dir
# mri_coreg
# spmimg2bvolume
# fsf-kmnacf
# getsesspath
# mcparams2extreg
# functwf-sess
# getfirstsliceno
# isxconcat0-sess
# fcseed-config
# mkblockpar
# getnrows
# cmpsesssnr-sess
# getfirstrundir-sess
# isxavg-fe-sess-1.3
# isxavg-fe
# stc.fsl
# crossrun.ffx.fsf
# getmatlab
# mkfeat-sess
# seqefficiency
# par2fsl3
# fcseedcor
# difffsfast
# lrst-blk-sess
# getstem
# evfunc
# splitstr
# fsf-kmracf
# ghostdet-sess
# fcseed-sess
# compress-sess
# checkmincdir
# rawfunc2tal
# feat.fsfast-patch.tcl
# isxavg-re-sess
# par2kspar
# cmpsnr-sess
# tkregister-sess
# fast_getext
# mkcmanova-sess
# evspatfil-sess
# sxacfg-get
# mktemplate-sess
# mkvoxshiftmap
# synthrawroi
# synth-sess
# sliceview-sess
# mc-afni2
# fixseqinfo-sess
# functcvm
# bgmask-sess
# geticoorder
# stc-sess
# preproc-sess
# gettalres
# stripsessargs
# mktalreg
# reg2subj
# funcroi-table-sess
# groupreg-sess
# glmfourier
# aseg2funcmask-sess
# mkcontrast2
# getpwdcmd
# autoreg-fsl
# bfileconvert
# cordiff
# roiavg
# optseq
# rawfunc2surf-sess
# check-sliceres-sess
# diag-optseq
# rawfunc2tal-sess
# fsfeat
# mcdat2mcextreg
# mris_glm-sess
# mc-afni
# meanimg
# fslregister-sess
# funcroi-config
# fsfeat-sess
# selxavg-sess-perrun
# bfvcheck
# mkcontrast-sess
# rawavg-sess
# getformat_from_stem
# par2fsl
# evpve-sess
# getbfvdim
# countncond
# prmerge-sess
# fsfeatffx
# evfunc-sess
# roitxt2tbl
# avgraw
# addmcparams
# rocview
# cp-bvolume
# plot-pve
# getncols
# getana
# cat-bvolume
# kmacfcond-sess
# fwhmest
# autoreg-sess
# spatialsmooth-sess
# subject-sess
# fast-log-preamble.csh
# synthstudy
# parse-measasc
# isxavg-fe-sess
# mkdesmtx-sess
# mkprestimcon
# getfullpath
# ghostdet
# mkcontrast
# isxavg-re-abb-sess
# glmstats
# getnconds
# evspatfil
# stem2fmt
# qmedit
# isxavg-re
# par2schedule
# getendian
# du-sess
# selxavg-jk-sess
# getspacetype
# conmask-sess
# spikedet-sess
# getlastsliceno
# ipfsl
# fsf-glmfit
# mkbrainmask
# fieldsign-sess
# acorfunc-sess
# roiavgraw
# glmfourier-sess
# acfseg-sess
# getnslices
# mkbrainmask-sess
# clusterspec2mask
# mkmosaic
# optseq.matlab
# spmregister-sess
# fwhmest-sess
# fsfast-gui-bug
# getsliceno
# spikedet
# diag-fmri
# plot-twf-sess
# mc-sess
# mkanalysis-sess
# isxconcat-sess
# tksurfer-sess
# lrst-blk
# isxavg-fe-abb-sess
# kmacfwht-sess
# isroiavg
# func2acf
# qsurfer
# glmest
# surfsmooth-sess
# concat-bvolumes
# cluster-sess
# getslicestr
# kmacf-sess
# register-sess
# functcvm-sess
# mkdesignmtx
# par2stf
# mkfieldsign
# vlrmerge
# fsl2par
# surf-sess
# func2label
# selxavg2
# selxavg-sess
# getrunlist
# mktalxfm-sess
# fcreg-sess
# feat.fsfast-patch
# funcroi-sess
# df-sess
# tar-sess
# cmpanalyses-sess
# roixrunsum-sess
# getbext
# getnframes
# fsfast-version
# isargflag
# tkmedit-sess
# flacproc-sess
# selxavg3-sess
# tkm_dialog.tcl
# tkregister2_cmdl
# tkmedit
# tkm_graph.tcl
# tkregister.tcl
# tksurfer.bin
# tkregister2.bin
# tkmedit.tcl
# tkUtils.tcl
# tkanalyse.tcl
# tkm_common.tcl
# tkm_wrappers.tcl
# tkregister
# tksurfer.tcl
# tkregister2.tcl
# tkregister2
# tkm_functional.tcl
# fsgdfPlot.tcl
# tksurfer
# tkmedit.bin
# fslfft
# msmapplywarp
# qboot_postproc.sh
# swap_voxelwise
# fslecho
# fslstats
# wpng
# first_mult_bcorr
# bedpostx
# filmbabe
# featregapply
# img2stdcoord
# ptoz
# asl_calib
# dtigen
# bedpost
# medianfilter
# melodic
# label2surf
# convertwarp
# extractfidparams
# fsl_boxplot
# morph_kernel
# fnirtfileutils
# checkFEAT
# tcalc
# cluster
# setup_masks
# slicesdir
# ttoz
# Flirt_gui
# select_dwi_vols
# tbss_3_postreg
# viena_createpng
# fsl_glm
# connectedcomp
# siena
# tbss_fill
# asl_file
# Nudge_gui
# tbss_deproject
# sienax
# fslascii2img
# sliceanimate
# quasil
# Asl_gui
# midtrans
# fsladd
# hist2prob
# fslmodhd
# topup
# generate_b0
# mean
# siena_diff
# slices
# b0calc
# qboot_parallel
# fslnvols
# fnirt
# calculatevertexwisecorr
# new_invwarp
# mainfeatreg
# first_roi_slicesdir
# asl_mfree
# aff2rigid
# gps
# applyxfm4D
# fugue
# baycest
# fslpspec
# imtest
# fdt_rotate_bvecs
# slicer
# drawmesh
# first_utils
# fslval
# eddy_cuda
# rmsdiff
# feat
# Glm_gui
# verbena
# surf_proj
# slices_summary
# msmresamplemetric
# fslmaths
# first
# fdr
# dtifit
# Text2Vest
# featquery
# estimate_curvature
# eddy_combine
# msmresample
# generate_brain
# fsl_gui
# tbss_sym
# possum_matrix
# invwarp
# fslchfiletype_exe
# cutoffcalc
# contrast_mgr
# ftoz
# avw2fsl
# halfcosbasis
# probtrack
# possum_sum
# selfintersection
# zeropad
# randomise_parallel
# fsl
# pulse
# fslcc
# fslsmoothfill
# make_bianca_mask
# tbss_1_preproc
# tsplot
# fast
# pnm_stage1
# tbss_4_prestats
# fslwish
# bedpostx_datacheck
# Possum_gui
# fsl_tsplot
# run_mesh_utils
# eddy
# fslvbm_3_proc
# Pnm_gui
# smoothest
# basil
# fslinterleave
# fslsurfacemaths
# first3Dview
# whirlgif
# Bet_gui
# Susan_gui
# applytopup
# surf2surf
# vecreg
# pvmfit
# fsl_sub
# film_gls
# Fdt_gui
# fslvbm_1_bet
# Melodic_gui
# fsltclsh
# remove_ext
# fabber
# proj_thresh
# epi_reg
# eddy_correct
# bet2
# perfusion_subtract
# pngappend
# surfconvert
# fsl_regfilt
# make_dyadic_vectors
# create_lut
# fslipython
# fslcreatehd
# filmbabescript
# asl_reg
# fslcomplex
# AnatomicalAverage
# distancemap
# fslmeants
# qboot
# pairreg
# ApplyXFM_gui
# fsl_histogram
# bedpostx_preproc.sh
# Vest2Text
# invwarp_exe
# mcflirt
# estimate_strains
# asl_preproc
# Feat_gui
# fsl_prepare_fieldmap
# fsl2ascii
# fsl_anat
# easythresh
# generate_b0calc
# robustfov
# Fsl_prepare_fieldmap_gui
# siena_cal
# fslview
# mist
# setFEAT
# betsurf
# mccutup
# tbss_x
# mp_diffpow.sh
# fslhd
# feat_model
# flameo
# std2imgcoord
# possumX
# fsl_schurprod
# systemnoise
# xfibres
# first_boundary_corr
# fsl_sbca
# fslselectvols
# fslchpixdim
# mist_FA_reg
# fdt_matrix_merge
# tbss_2_reg
# invfeatreg
# lesion_filling
# susan
# immv
# mist_mesh_utils
# avscale
# fslinfo
# randomise
# fsl_motion_outliers
# first_flirt
# feat_gm_prepare
# spharm_rm
# concat_bvars
# run_first
# slicesmask
# bet
# extracttxt
# msm
# mm
# cluster2html
# fslroi
# pointflirt
# unconfound
# possumX_postproc.sh
# calc_grad_perc_dev
# signal2image
# estimate_metric_distortion
# fslslice
# applywarp
# popp
# fsleyes
# atlasquery
# fsl_mvlm
# probtrackx
# slicetimer
# dual_regression
# fslswapdim
# updatefeatreg
# fslerrorreport
# fslreorient2std
# fslchfiletype
# tmpnam
# imcp
# old_betall
# fslpython
# bedpostx_single_slice.sh
# fslmerge
# mist_1_train
# imglob
# maskdyads
# mist_2_fit
# Fast_gui
# ConcatXFM_gui
# match_smoothing
# fslorient
# sigloss
# makerot
# viena_quant
# tbss_non_FA
# prewhiten
# ztop
# img2imgcoord
# prelude
# fslanimate
# InvertXFM_gui
# mist_display
# fslFixText
# average_surfaces
# surface_fdr
# ttologp
# fslview_deprecated
# atlasq
# fsl_abspath
# bianca
# fslswapdim_exe
# imln
# estnoise
# msm_metricmath
# possum_plot.py
# surf2volume
# ccops
# tbss_skeleton
# overlay
# siena_flirt
# probtrackx2
# Renderstats_gui
# basil_var
# mvntool
# oxford_asl
# fsledithd
# atlasquery_bin
# film_cifti
# surfmaths
# bianca_cluster_stats
# renderhighres
# run_first_all
# bianca_overlap_measures
# fslsize
# siena_flow2std
# find_the_biggest
# fslcorrecthd
# Runtcl
# fslsplit
# Renderhighres_gui
# convert_xfm
# Featquery_gui
# pnm_evs
# imrm
# fslvbm_2_template
# fsl_reg
# autoaq
# standard_space_roi
# fslcpgeom
# flirt_average
# qboot_preproc.sh
# Make_flobs_gui
# fabber_var
# generateConfounds
# design_ttest2
# possum_interpmot.py
# swap_subjectwise
# possum
# flirt
# bedpostx_postproc.sh
# nii2mnc
# mincheader
# field2imp
# mincreshape
# mincpik
# crispify
# mincresample
# autocrop
# volume_stats
# nu_evaluate
# mincmath
# nu_estimate_np_and_em
# volume_hist
# xfminvert
# spline_smooth
# xfm2param
# xfmconcat
# mnc2nii
# mritotal
# mincdiff
# sharpen_hist
# minctoecat
# mincwindow
# mincchamfer
# sharpen_volume
# mincstats
# imp2field
# ecattominc
# nu_correct
# nu_estimate
# extracttag
# upet2mnc
# voxeltoworld
# mritoself
# minc_modify_header
# minchistory
# make_phantom
# mincview
# rand_param
# transformtags
# minclookup
# correct_field
# mincblur
# minctoraw
# dcm2mnc
# check_scale
# minctracc
# ncdump
# mincinfo
# worldtovoxel
# mincedit
# param2xfm
# rawtominc
# minccalc
# xfmtool
# make_model
# volume_cog
# resample_labels
# evaluate_field
# mincaverage
# invert_raw_image
# mincbbox
# mincextract
# mincexpand
# make_template
# xcorr_vol
# mincmakescalar
# mincconcat
# ncgen
# mincmakevector
# zscore_vol
# minccopy
# fslfft
# msmapplywarp
# qboot_postproc.sh
# swap_voxelwise
# fslecho
# fslstats
# wpng
# first_mult_bcorr
# bedpostx
# filmbabe
# featregapply
# img2stdcoord
# ptoz
# asl_calib
# dtigen
# bedpost
# medianfilter
# melodic
# label2surf
# convertwarp
# extractfidparams
# fsl_boxplot
# morph_kernel
# fnirtfileutils
# checkFEAT
# tcalc
# cluster
# setup_masks
# slicesdir
# ttoz
# Flirt_gui
# select_dwi_vols
# tbss_3_postreg
# viena_createpng
# fsl_glm
# connectedcomp
# siena
# tbss_fill
# asl_file
# Nudge_gui
# tbss_deproject
# sienax
# fslascii2img
# sliceanimate
# quasil
# Asl_gui
# midtrans
# fsladd
# hist2prob
# fslmodhd
# topup
# generate_b0
# mean
# siena_diff
# slices
# b0calc
# qboot_parallel
# fslnvols
# fnirt
# calculatevertexwisecorr
# new_invwarp
# mainfeatreg
# first_roi_slicesdir
# asl_mfree
# aff2rigid
# gps
# applyxfm4D
# fugue
# baycest
# fslpspec
# imtest
# fdt_rotate_bvecs
# slicer
# drawmesh
# first_utils
# fslval
# eddy_cuda
# rmsdiff
# feat
# Glm_gui
# verbena
# surf_proj
# slices_summary
# msmresamplemetric
# fslmaths
# first
# fdr
# dtifit
# Text2Vest
# featquery
# estimate_curvature
# eddy_combine
# msmresample
# generate_brain
# fsl_gui
# tbss_sym
# possum_matrix
# invwarp
# fslchfiletype_exe
# cutoffcalc
# contrast_mgr
# ftoz
# avw2fsl
# halfcosbasis
# probtrack
# possum_sum
# selfintersection
# zeropad
# randomise_parallel
# fsl
# pulse
# fslcc
# fslsmoothfill
# make_bianca_mask
# tbss_1_preproc
# tsplot
# fast
# pnm_stage1
# tbss_4_prestats
# fslwish
# bedpostx_datacheck
# Possum_gui
# fsl_tsplot
# run_mesh_utils
# eddy
# fslvbm_3_proc
# Pnm_gui
# smoothest
# basil
# fslinterleave
# fslsurfacemaths
# first3Dview
# whirlgif
# Bet_gui
# Susan_gui
# applytopup
# surf2surf
# vecreg
# pvmfit
# fsl_sub
# film_gls
# Fdt_gui
# fslvbm_1_bet
# Melodic_gui
# fsltclsh
# remove_ext
# fabber
# proj_thresh
# epi_reg
# eddy_correct
# bet2
# perfusion_subtract
# pngappend
# surfconvert
# fsl_regfilt
# make_dyadic_vectors
# create_lut
# fslipython
# fslcreatehd
# filmbabescript
# asl_reg
# fslcomplex
# AnatomicalAverage
# distancemap
# fslmeants
# qboot
# pairreg
# ApplyXFM_gui
# fsl_histogram
# bedpostx_preproc.sh
# Vest2Text
# invwarp_exe
# mcflirt
# estimate_strains
# asl_preproc
# Feat_gui
# fsl_prepare_fieldmap
# fsl2ascii
# fsl_anat
# easythresh
# generate_b0calc
# robustfov
# Fsl_prepare_fieldmap_gui
# siena_cal
# fslview
# mist
# setFEAT
# betsurf
# mccutup
# tbss_x
# mp_diffpow.sh
# fslhd
# feat_model
# flameo
# std2imgcoord
# possumX
# fsl_schurprod
# systemnoise
# xfibres
# first_boundary_corr
# fsl_sbca
# fslselectvols
# fslchpixdim
# mist_FA_reg
# fdt_matrix_merge
# tbss_2_reg
# invfeatreg
# lesion_filling
# susan
# immv
# mist_mesh_utils
# avscale
# fslinfo
# randomise
# fsl_motion_outliers
# first_flirt
# feat_gm_prepare
# spharm_rm
# concat_bvars
# run_first
# slicesmask
# bet
# extracttxt
# msm
# mm
# cluster2html
# fslroi
# pointflirt
# unconfound
# possumX_postproc.sh
# calc_grad_perc_dev
# signal2image
# estimate_metric_distortion
# fslslice
# applywarp
# popp
# fsleyes
# atlasquery
# fsl_mvlm
# probtrackx
# slicetimer
# dual_regression
# fslswapdim
# updatefeatreg
# fslerrorreport
# fslreorient2std
# fslchfiletype
# tmpnam
# imcp
# old_betall
# fslpython
# bedpostx_single_slice.sh
# fslmerge
# mist_1_train
# imglob
# maskdyads
# mist_2_fit
# Fast_gui
# ConcatXFM_gui
# match_smoothing
# fslorient
# sigloss
# makerot
# viena_quant
# tbss_non_FA
# prewhiten
# ztop
# img2imgcoord
# prelude
# fslanimate
# InvertXFM_gui
# mist_display
# fslFixText
# average_surfaces
# surface_fdr
# ttologp
# fslview_deprecated
# atlasq
# fsl_abspath
# bianca
# fslswapdim_exe
# imln
# estnoise
# msm_metricmath
# possum_plot.py
# surf2volume
# ccops
# tbss_skeleton
# overlay
# siena_flirt
# probtrackx2
# Renderstats_gui
# basil_var
# mvntool
# oxford_asl
# fsledithd
# atlasquery_bin
# film_cifti
# surfmaths
# bianca_cluster_stats
# renderhighres
# run_first_all
# bianca_overlap_measures
# fslsize
# siena_flow2std
# find_the_biggest
# fslcorrecthd
# Runtcl
# fslsplit
# Renderhighres_gui
# convert_xfm
# Featquery_gui
# pnm_evs
# imrm
# fslvbm_2_template
# fsl_reg
# autoaq
# standard_space_roi
# fslcpgeom
# flirt_average
# qboot_preproc.sh
# Make_flobs_gui
# fabber_var
# generateConfounds
# design_ttest2
# possum_interpmot.py
# swap_subjectwise
# possum
# flirt
# bedpostx_postproc.sh
# ppmtouil
# pip3.7
# lzmainfo
# xwdtopnm
# ppmtorgb3
# pamtohdiff
# pbmtoppa
# pyenv
# ccmake
# ppmtoyuvsplit
# pbmtonokia
# dot2gxl
# leaftoppm
# smtpd2.7.py
# Rscript
# fmriprep-docker
# pnminvert
# pkg-config
# pbmpage
# sos-runner
# pnmrotate
# bdftogd
# idle2.7
# pgmslice
# nib-diff
# ppmshadow
# anytopnm
# asciitopgm
# ppmtoppm
# pgmkernel
# tifftopnm
# c++-9
# pbmtoescp2
# ppmcie
# x86_64-apple-darwin19-gcc-9
# ddbugtopbm
# pgmhist
# rawtoppm
# webpng
# pnmcut
# pnmhistmap
# palmtopnm
# pamseq
# nipy_tsdiffana
# fitstopnm
# pampick
# tctmttest
# pngtopam
# idle
# ppmmix
# wget
# heudiconv_monitor
# pnmtofits
# pamrecolor
# pgmmake
# markdown_py
# jupyter-run
# pbmtog3
# cluster
# pbmtomrf
# pamtilt
# spython
# pbmtodjvurle
# tchtest
# gv2gml
# dipy_track_det
# dipy_fit_dti
# xzdec
# tiffsplit
# pambayer
# gxl2dot
# ppmforge
# pnmtosgi
# ppmtojpeg
# wheel3
# mtvtoppm
# pamstretch
# python2-config
# pigz
# fax2tiff
# tred
# pamfunc
# prov-compare
# pcdovtoppm
# git-receive-pack
# pnmnoraw
# docker
# fc-list
# gcov-tool-9
# pnmpaste
# pamsharpness
# pyenv-install
# unflatten
# ppmtoilbm
# texi2pdf
# 2to3-2.7
# jupyter-nbextension
# lispmtopgm
# gtester
# ppmrainbow
# pbmtopgm
# pnmtops
# pbmtocis
# autoscan
# notary
# gd2togif
# docker-machine
# 411toppm
# pip2
# gcc-ranlib-9
# gfortran
# mm2gv
# 2to3
# pbmtoxbm
# hyperkit
# ppmfade
# pamperspective
# python3
# pnmtoddif
# wish8.6
# tcfmgr
# png-fix-itxt
# dot
# pamslice
# pamsharpmap
# ppmtotga
# pbmtowbmp
# pgmenhance
# apm
# heudiconv
# jbigtopnm
# pgmtosbig
# fieldmap_intendedfor.py
# cmake
# ppmflash
# tiffdump
# pamaddnoise
# g++-9
# pytest
# pbmtogem
# ppmspread
# ppmddumpfont
# gitk
# easy_install
# fc-pattern
# ilbmtoppm
# pbmtox10bm
# pnmfile
# pydoc
# dipy_fit_csa
# python
# python2
# unxz
# ppmdmkfont
# tcbmgr
# pythonw
# pbmtolps
# tiff2bw
# gfortran-4.2
# pammasksharpen
# jiv
# atom
# freetype-config
# pip3
# pgmnorm
# sed
# sunicontopnm
# gdbus-codegen
# fc-validate
# pamtopdbimg
# cjpeg
# autom4te
# ipython
# ppmchange
# nib-dicomfs
# escp2topbm
# jpegtran
# gvpack
# pbmminkowski
# libpng16-config
# yuvtoppm
# xzegrep
# gsettings
# gv2gxl
# VBoxManage
# pngfix
# python3.7-config
# zeisstopnm
# python2.7-config
# dipy_fit_dki
# glib-compile-schemas
# webpmux
# pamscale
# pgmtopgm
# fc-query
# tiffcmp
# pnmtopng
# cameratopam
# pnmtojpeg
# yuvsplittoppm
# rasttopnm
# ppmtopjxl
# tiff2pdf
# pbmtoicon
# pbmreduce
# ppmdist
# jupyter-notebook
# pamsistoaglyph
# twopi
# dipy_median_otsu
# pbmtozinc
# unlzma
# pgmtexture
# pbmto4425
# ppmdim
# pbmpscale
# ppmtopuzz
# ybmtopbm
# pbmtomgr
# pbmtopi3
# hdifftopam
# pamexec
# ppmtowinicon
# easy_install-3.7
# diffimg
# pktopbm
# pgmtolispm
# fiascotopnm
# pamdepth
# VBoxHeadless
# prov-convert
# pnmarith
# pyenv-uninstall
# pjtoppm
# pyvenv-3.7
# xzfgrep
# pasteurize
# sirtopnm
# nipy_4dto3d
# webpinfo
# tcumttest
# gdtopng
# libpng-config
# pnmscalefixed
# gdbm_dump
# pbmtomda
# git-credential-netrc
# pod2texi
# isympy
# graphml2gv
# pamtompfont
# gobject-query
# brushtopbm
# kubectl.docker
# nipy_3dto4d
# pnmsmooth
# pnmenlarge
# brew
# pnmtopclxl
# fstopgm
# pgmdeshadow
# ppmtopi1
# ppmdcfont
# BIDS_conversion_R33.sh
# bmptopnm
# pnminterp
# g3topbm
# pbmtoascii
# pnmcrop
# pnmtopalm
# R
# pamsplit
# idle2
# tcucodec
# pbmlife
# pamundice
# xpmtoppm
# rletopnm
# pngtogd2
# csv2rdf
# sgitopnm
# pbmtoepsi
# wheel
# sldtoppm
# patchwork
# tclsh8.6
# tctmgr
# pnmflip
# eyuvtoppm
# pydoc2.7
# powerpc-apple-darwin8-gfortran-4.2
# x86_64-apple-darwin19-gcc-ranlib-9
# nipy_4d_realign
# autoupdate
# pnmtosir
# sccmap
# pambackground
# manweb
# i686-apple-darwin8-gfortran-4.2
# pdbimgtopam
# jpeg2ktopam
# pnmtotiff
# pamshadedrelief
# python3.7m
# git-upload-archive
# smtpd2.py
# mdatopbm
# ppmtoeyuv
# ppmntsc
# djpeg
# gfortran-uninstall
# picttoppm
# dipy_nlmeans
# giftopnm
# pythonw2.7
# pnmindex
# pnmshear
# pnmtile
# annotate
# pamtopnm
# pamunlookup
# tiffcrop
# neotoppm
# wbmptopbm
# pbmtobbnbg
# nib-trk2tck
# gvmap
# pamrgbatopng
# rlatopam
# nib-ls
# python3.7m-config
# pgmramp
# pnmcomp
# pamtooctaveimg
# gio-querymodules
# docker-credential-osxkeychain
# pamtohtmltbl
# ppmtoneo
# ppmtosixel
# pnmtorast
# pnmhisteq
# gemtopbm
# flea
# idle3
# gdcmpgif
# gapplication
# python3.7
# dipy_fit_mapmri
# xz
# ppmdither
# tchmgr
# pi1toppm
# pampaintspill
# spctoppm
# VirtualBox
# pbmtomatrixorbital
# gdparttopng
# mgrtopbm
# ximtoppm
# glib-compile-resources
# chardetect
# pamtogif
# ppmtoacad
# vboxwebsrv
# tchmttest
# cpp-9
# parrec2nii
# pamdice
# macptopbm
# pamtosvg
# pbmtogo
# VBoxDTrace
# neato
# ppmtolj
# ppmtoxpm
# img2webp
# texindex
# pamstretch-gen
# pbmmask
# python-config
# ppmglobe
# tiffdither
# sputoppm
# x86_64-apple-darwin19-gcc-nm-9
# cmuwmtopbm
# htop
# rdfgraphisomorphism
# pngtopnm
# dipy_mask
# pamstereogram
# python3-config
# info
# ipython3
# tiffset
# pip
# pamflip
# pfmtopam
# avstopam
# tgatoppm
# giftogd2
# pbmtextps
# ppmpat
# pamtoxvmini
# hpcdtoppm
# pynets
# pi3topbm
# python-build
# pbmtoepson
# pnmnorm
# ppmtobmp
# tiff2ps
# pynets_run.py
# pnmtoxwd
# futurize
# pamcrater
# osage
# qrttoppm
# ppmtoarbtxt
# gcov-dump-9
# ppm3d
# neurodocker
# pamcomp
# cmake-gui
# lzless
# rdf2dot
# cistopbm
# pamedge
# gvgen
# easy_install-2.7
# pbmtoatk
# x86_64-apple-darwin19-gcc-ar-9
# ppmtoterm
# vbox-img
# tiffinfo
# pythonw2
# docker-credential-desktop
# jupyter-nbconvert
# ppmdraw
# pnmconvol
# pgmoil
# gresource
# bioradtopgm
# jsonschema
# psidtopgm
# tcfmttest
# pamtopfm
# dipy_info
# pamtojpeg2k
# smime_keys
# pamwipeout
# pamsummcol
# jpegtopnm
# glibtool
# gcc-nm-9
# hipstopgm
# BIDS_conversion_ADM.sh
# ppmtopict
# tqdm
# gfortran-4.0
# pnmcat
# pgmminkowski
# gvpr
# rdfpipe
# gtester-report
# nop
# pc1toppm
# pgmabel
# atktopbm
# ppmtogif
# pbmclean
# glibtoolize
# ppmrelief
# ctest
# jupyter-troubleshoot
# pamfixtrunc
# xzless
# pal2rgb
# dipy_fit_csd
# tcbmttest
# VBoxBalloonCtrl
# lzcmp
# pnmstitch
# circo
# gd2topng
# ppmtoicr
# pygmentize
# xzcat
# mrftopbm
# gxl2gv
# xcpengine-singularity
# jupyter-migrate
# pamthreshold
# autoreconf
# pamstack
# VBoxAutostart
# pgpring
# pbmtocmuwm
# nipypecli
# dipy_reslice
# wrjpgcom
# pnmtofiasco
# gfortran-9
# fv_export_local-itadmin.sh
# nitool
# pydoc3.7
# ppmquant
# autoconf
# texi2dvi
# pbmtoplot
# pbmmake
# pnmtotiffcmyk
# pamtoavs
# pbmtosunicon
# pamsumm
# pnmpsnr
# vpnkit
# ppmtopgm
# acyclic
# pbmtopk
# gml2gv
# gdlib-config
# tabulate
# pgmbentley
# autoheader
# pamendian
# imginfo
# rawtopgm
# pcretest
# VBoxBugReport
# glib-gettextize
# xzcmp
# pamtofits
# gouldtoppm
# unpigz
# dcmstack
# lzcat
# bidsify
# pnmtorle
# pamoil
# pbmtoibm23xx
# git-credential-osxkeychain
# sfdp
# gc
# xcpengine-docker
# pgmmedian
# gcov-9
# 2to3-2
# python2.7
# pammixinterlace
# pbmtopsg3
# gcc-ar-9
# fc-cache
# ppmtopj
# pampop9
# idle3.7
# pnmremap
# gdbus
# pcxtoppm
# fc-cat
# pdftexi2dvi
# pydeface.py
# ppmtospu
# git-cvsserver
# ppmcolors
# ppmtoleaf
# infokey
# lzdiff
# nipy_diagnose
# pgmtost4
# dijkstra
# pip2.7
# pnmtopnm
# pgmedge
# pamvalidate
# gdbmtool
# sbigtopgm
# jupyter-console
# tcbtest
# pamtotiff
# tcutest
# glib-genmarshal
# pcre-config
# nib-tck2trk
# pyvenv
# ppmhist
# tcttest
# dot_builtins
# prune
# winicontoppm
# git-shell
# pgmmorphconv
# pamlookup
# dwebp
# xbmtopbm
# plasma_store
# nib-nifti-dx
# ppmtoyuv
# ppmtomap
# pgmcrater
# ifnames
# pnmalias
# pnmcolormap
# pgmtopbm
# mutt
# texi2any
# pbmto10x
# ppmtopcx
# gd2copypal
# ppmrough
# ppmmake
# jupyter-serverextension
# lzmadec
# iptest3
# fax2ps
# pnmmercator
# node
# rgb3toppm
# fc-match
# : 1

# %%
#Young adults

cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_young/stats

Text2Vest design_age_alpha.txt design_age_alpha.mat

# %% [markdown]
# Check design matrices and contrasts by opening them with TextEdit. (Drag file to TextEdit icon in dock)

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/stats

randomise -i all_FA -o tbss_old_age_d -m mean_FA_mask -d design_age_d.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_old_alpha_d -m mean_FA_mask -d design_alpha_d.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_old_IS_d -m mean_FA_mask -d design_IS_d.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_old_IV -m mean_FA_mask -d design_IV_d.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_old_RA -m mean_FA_mask -d design_RA_d.mat -t design_CR.con -n 500 --T2 -D
# Out:
# @ScaleVolume
# @afni.run.me
# @ShowDynamicRange
# 3dpc
# 3dAFNItoNIML
# @Install_MEICA_Demo
# tokens
# align_epi_anat.py
# 1dAstrip
# TT_N27_EZ_LR+tlrc.BRIK.gz
# FATCAT_matplot
# plug_reorder.so
# 3dttest
# 3dAFNItoRaw
# gifti_tool
# 3dnoise
# libgslcblas.0.dylib
# 3dMEMA.R
# plug_nth_dataset.so
# uber_align_test.py
# 3dICA.R
# TT_EPI+tlrc.HEAD
# abids_tool.py
# @djunct_4d_imager
# 3dNwarpApply
# @2dwarper
# fat_mvm_review.py
# @compute_gcor
# 3dNwarpCalc
# InstaTract
# unWarpEPI.py
# imrotate
# 3dUpsample
# 3dTsort
# 3dPeriodogram
# 3dmaxima
# @R_funclist
# 1dSEM
# imreg
# adwarp
# 3dNetCorr
# @NoPound
# plug_realtime.so
# libgomp.1.dylib
# @djunct_4d_slices_to_3d_vol
# 3dBlurInMask
# gen_ss_review_scripts.py
# scan_niml_vals.csh
# 1dTsort
# TT_caez_pmaps_18+tlrc.HEAD
# model_constant.so
# TT_desai_dk_mpm+tlrc.BRIK.gz
# 1deval
# 3dhistog
# gen_ss_review_table.py
# 2dImReg
# uber_proc.py
# sqwave
# 3dSetupGroupInCorr
# plug_scatplot.so
# 3dkmeans
# 3dMVM.R
# @FromRAI
# TT_N27+tlrc.HEAD
# FSread_annot
# afni_vcheck
# MNIa_caez_gw_18+tlrc.HEAD
# afni_system_check.py
# 3dRegAna
# rmz
# 2perm
# 3dRprogDemo
# 3dFDR
# fat_proc_decmap
# 3dRSFC
# aiv
# 3dFourier
# 3dSurfMask
# 3drefit
# qhull
# @VolCenter
# Circadian-Measures-and-DTI.html
# OHBM 2020.Rmd
# Untitled.ipynb
# tbss.sh
# CC Volume.Rmd
# CC-Volume.html
# Circadian-Measures-and-DTI_files
# Circadian Measures and DTI.Rmd
# .ipynb_checkpoints
# dti_dsnmat.R
# OHBM-2020.html
# Circadian-Measures-and-DTI_files
# .ipynb_checkpoints
# [1]+  Done                    compgen -cdfa  (wd: ~/GitHub/aging-study/analysis/dti)
# (wd now: /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/stats)
# randomise options: -i all_FA -o tbss_old_age_alpha -m mean_FA_mask -d design_age_alpha.mat -t design_age_CR.con -n 500 --T2
# Loading Data:
# Data loaded
# 8.48191e+65 permutations required for exhaustive test of t-test 1
# Doing 500 random permutations
# Starting permutation 1 (Unpermuted data)
# Starting permutation 2
# Starting permutation 3
# Starting permutation 4
# Starting permutation 5
# Starting permutation 6
# Starting permutation 7
# Starting permutation 8
# Starting permutation 9
# Starting permutation 10
# Starting permutation 11
# Starting permutation 12
# Starting permutation 13
# Starting permutation 14
# Starting permutation 15
# Starting permutation 16
# Starting permutation 17
# Starting permutation 18
# Starting permutation 19
# Starting permutation 20
# Starting permutation 21
# Starting permutation 22
# Starting permutation 23
# Starting permutation 24
# Starting permutation 25
# Starting permutation 26
# Starting permutation 27
# Starting permutation 28
# Starting permutation 29
# Starting permutation 30
# Starting permutation 31
# Starting permutation 32
# Starting permutation 33
# Starting permutation 34
# Starting permutation 35
# Starting permutation 36
# Starting permutation 37
# Starting permutation 38
# Starting permutation 39
# Starting permutation 40
# Starting permutation 41
# Starting permutation 42
# Starting permutation 43
# Starting permutation 44
# Starting permutation 45
# Starting permutation 46
# Starting permutation 47
# Starting permutation 48
# Starting permutation 49
# Starting permutation 50
# Starting permutation 51
# Starting permutation 52
# Starting permutation 53
# Starting permutation 54
# Starting permutation 55
# Starting permutation 56
# Starting permutation 57
# Starting permutation 58
# Starting permutation 59
# Starting permutation 60
# Starting permutation 61
# Starting permutation 62
# Starting permutation 63
# Starting permutation 64
# Starting permutation 65
# Starting permutation 66
# Starting permutation 67
# Starting permutation 68
# Starting permutation 69
# Starting permutation 70
# Starting permutation 71
# Starting permutation 72
# Starting permutation 73
# Starting permutation 74
# Starting permutation 75
# Starting permutation 76
# Starting permutation 77
# Starting permutation 78
# Starting permutation 79
# Starting permutation 80
# Starting permutation 81
# Starting permutation 82
# Starting permutation 83
# Starting permutation 84
# Starting permutation 85
# Starting permutation 86
# Starting permutation 87
# Starting permutation 88
# Starting permutation 89
# Starting permutation 90
# Starting permutation 91
# Starting permutation 92
# Starting permutation 93
# Starting permutation 94
# Starting permutation 95
# Starting permutation 96
# Starting permutation 97
# Starting permutation 98
# Starting permutation 99
# Starting permutation 100
# Starting permutation 101
# Starting permutation 102
# Starting permutation 103
# Starting permutation 104
# Starting permutation 105
# Starting permutation 106
# Starting permutation 107
# Starting permutation 108
# Starting permutation 109
# Starting permutation 110
# Starting permutation 111
# Starting permutation 112
# Starting permutation 113
# Starting permutation 114
# Starting permutation 115
# Starting permutation 116
# Starting permutation 117
# Starting permutation 118
# Starting permutation 119
# Starting permutation 120
# Starting permutation 121
# Starting permutation 122
# Starting permutation 123
# Starting permutation 124
# Starting permutation 125
# Starting permutation 126
# Starting permutation 127
# Starting permutation 128
# Starting permutation 129
# Starting permutation 130
# Starting permutation 131
# Starting permutation 132
# Starting permutation 133
# Starting permutation 134
# Starting permutation 135
# Starting permutation 136
# Starting permutation 137
# Starting permutation 138
# Starting permutation 139
# Starting permutation 140
# Starting permutation 141
# Starting permutation 142
# Starting permutation 143
# Starting permutation 144
# Starting permutation 145
# Starting permutation 146
# Starting permutation 147
# Starting permutation 148
# Starting permutation 149
# Starting permutation 150
# Starting permutation 151
# Starting permutation 152
# Starting permutation 153
# Starting permutation 154
# Starting permutation 155
# Starting permutation 156
# Starting permutation 157
# Starting permutation 158
# Starting permutation 159
# Starting permutation 160
# Starting permutation 161
# Starting permutation 162
# Starting permutation 163
# Starting permutation 164
# Starting permutation 165
# Starting permutation 166
# Starting permutation 167
# Starting permutation 168
# Starting permutation 169
# Starting permutation 170
# Starting permutation 171
# Starting permutation 172
# Starting permutation 173
# Starting permutation 174
# Starting permutation 175
# Starting permutation 176
# Starting permutation 177
# Starting permutation 178
# Starting permutation 179
# Starting permutation 180
# Starting permutation 181
# Starting permutation 182
# Starting permutation 183
# Starting permutation 184
# Starting permutation 185
# Starting permutation 186
# Starting permutation 187
# Starting permutation 188
# Starting permutation 189
# Starting permutation 190
# Starting permutation 191
# Starting permutation 192
# Starting permutation 193
# Starting permutation 194
# Starting permutation 195
# Starting permutation 196
# Starting permutation 197
# Starting permutation 198
# Starting permutation 199
# Starting permutation 200
# Starting permutation 201
# Starting permutation 202
# Starting permutation 203
# Starting permutation 204
# Starting permutation 205
# Starting permutation 206
# Starting permutation 207
# Starting permutation 208
# Starting permutation 209
# Starting permutation 210
# Starting permutation 211
# Starting permutation 212
# Starting permutation 213
# Starting permutation 214
# Starting permutation 215
# Starting permutation 216
# Starting permutation 217
# Starting permutation 218
# Starting permutation 219
# Starting permutation 220
# Starting permutation 221
# Starting permutation 222
# Starting permutation 223
# Starting permutation 224
# Starting permutation 225
# Starting permutation 226
# Starting permutation 227
# Starting permutation 228
# Starting permutation 229
# Starting permutation 230
# Starting permutation 231
# Starting permutation 232
# Starting permutation 233
# Starting permutation 234
# Starting permutation 235
# Starting permutation 236
# Starting permutation 237
# Starting permutation 238
# Starting permutation 239
# Starting permutation 240
# Starting permutation 241
# Starting permutation 242
# Starting permutation 243
# Starting permutation 244
# Starting permutation 245
# Starting permutation 246
# Starting permutation 247
# Starting permutation 248
# Starting permutation 249
# Starting permutation 250
# Starting permutation 251
# Starting permutation 252
# Starting permutation 253
# Starting permutation 254
# Starting permutation 255
# Starting permutation 256
# Starting permutation 257
# Starting permutation 258
# Starting permutation 259
# Starting permutation 260
# Starting permutation 261
# Starting permutation 262
# Starting permutation 263
# Starting permutation 264
# Starting permutation 265
# Starting permutation 266
# Starting permutation 267
# Starting permutation 268
# Starting permutation 269
# Starting permutation 270
# Starting permutation 271
# Starting permutation 272
# Starting permutation 273
# Starting permutation 274
# Starting permutation 275
# Starting permutation 276
# Starting permutation 277
# Starting permutation 278
# Starting permutation 279
# Starting permutation 280
# Starting permutation 281
# Starting permutation 282
# Starting permutation 283
# Starting permutation 284
# Starting permutation 285
# Starting permutation 286
# Starting permutation 287
# Starting permutation 288
# Starting permutation 289
# Starting permutation 290
# Starting permutation 291
# Starting permutation 292
# Starting permutation 293
# Starting permutation 294
# Starting permutation 295
# Starting permutation 296
# Starting permutation 297
# Starting permutation 298
# Starting permutation 299
# Starting permutation 300
# Starting permutation 301
# Starting permutation 302
# Starting permutation 303
# Starting permutation 304
# Starting permutation 305
# Starting permutation 306
# Starting permutation 307
# Starting permutation 308
# Starting permutation 309
# Starting permutation 310
# Starting permutation 311
# Starting permutation 312
# Starting permutation 313
# Starting permutation 314
# Starting permutation 315
# Starting permutation 316
# Starting permutation 317
# Starting permutation 318
# Starting permutation 319
# Starting permutation 320
# Starting permutation 321
# Starting permutation 322
# Starting permutation 323
# Starting permutation 324
# Starting permutation 325
# Starting permutation 326
# Starting permutation 327
# Starting permutation 328
# Starting permutation 329
# Starting permutation 330
# Starting permutation 331
# Starting permutation 332
# Starting permutation 333
# Starting permutation 334
# Starting permutation 335
# Starting permutation 336
# Starting permutation 337
# Starting permutation 338
# Starting permutation 339
# Starting permutation 340
# Starting permutation 341
# Starting permutation 342
# Starting permutation 343
# Starting permutation 344
# Starting permutation 345
# Starting permutation 346
# Starting permutation 347
# Starting permutation 348
# Starting permutation 349
# Starting permutation 350
# Starting permutation 351
# Starting permutation 352
# Starting permutation 353
# Starting permutation 354
# Starting permutation 355
# Starting permutation 356
# Starting permutation 357
# Starting permutation 358
# Starting permutation 359
# Starting permutation 360
# Starting permutation 361
# Starting permutation 362
# Starting permutation 363
# Starting permutation 364
# Starting permutation 365
# Starting permutation 366
# Starting permutation 367
# Starting permutation 368
# Starting permutation 369
# Starting permutation 370
# Starting permutation 371
# Starting permutation 372
# Starting permutation 373
# Starting permutation 374
# Starting permutation 375
# Starting permutation 376
# Starting permutation 377
# Starting permutation 378
# Starting permutation 379
# Starting permutation 380
# Starting permutation 381
# Starting permutation 382
# Starting permutation 383
# Starting permutation 384
# Starting permutation 385
# Starting permutation 386
# Starting permutation 387
# Starting permutation 388
# Starting permutation 389
# Starting permutation 390
# Starting permutation 391
# Starting permutation 392
# Starting permutation 393
# Starting permutation 394
# Starting permutation 395
# Starting permutation 396
# Starting permutation 397
# Starting permutation 398
# Starting permutation 399
# Starting permutation 400
# Starting permutation 401
# Starting permutation 402
# Starting permutation 403
# Starting permutation 404
# Starting permutation 405
# Starting permutation 406
# Starting permutation 407
# Starting permutation 408
# Starting permutation 409
# Starting permutation 410
# Starting permutation 411
# Starting permutation 412
# Starting permutation 413
# Starting permutation 414
# Starting permutation 415
# Starting permutation 416
# Starting permutation 417
# Starting permutation 418
# Starting permutation 419
# Starting permutation 420
# Starting permutation 421
# Starting permutation 422
# Starting permutation 423
# Starting permutation 424
# Starting permutation 425
# Starting permutation 426
# Starting permutation 427
# Starting permutation 428
# Starting permutation 429
# Starting permutation 430
# Starting permutation 431
# Starting permutation 432
# Starting permutation 433
# Starting permutation 434
# Starting permutation 435
# Starting permutation 436
# Starting permutation 437
# Starting permutation 438
# Starting permutation 439
# Starting permutation 440
# Starting permutation 441
# Starting permutation 442
# Starting permutation 443
# Starting permutation 444
# Starting permutation 445
# Starting permutation 446
# Starting permutation 447
# Starting permutation 448
# Starting permutation 449
# Starting permutation 450
# Starting permutation 451
# Starting permutation 452
# Starting permutation 453
# Starting permutation 454
# Starting permutation 455
# Starting permutation 456
# Starting permutation 457
# Starting permutation 458
# Starting permutation 459
# Starting permutation 460
# Starting permutation 461
# Starting permutation 462
# Starting permutation 463
# Starting permutation 464
# Starting permutation 465
# Starting permutation 466
# Starting permutation 467
# Starting permutation 468
# Starting permutation 469
# Starting permutation 470
# Starting permutation 471
# Starting permutation 472
# Starting permutation 473
# Starting permutation 474
# Starting permutation 475
# Starting permutation 476
# Starting permutation 477
# Starting permutation 478
# Starting permutation 479
# Starting permutation 480
# Starting permutation 481
# Starting permutation 482
# Starting permutation 483
# Starting permutation 484
# Starting permutation 485
# Starting permutation 486
# Starting permutation 487
# Starting permutation 488
# Starting permutation 489
# Starting permutation 490
# Starting permutation 491
# Starting permutation 492
# Starting permutation 493
# Starting permutation 494
# Starting permutation 495
# Starting permutation 496
# Starting permutation 497
# Starting permutation 498
# Starting permutation 499
# Starting permutation 500
# Critical Value for: tbss_old_age_alpha_tfce_tstat1 is: 8.61707e+07
# 8.48191e+65 permutations required for exhaustive test of t-test 2
# Doing 500 random permutations
# Starting permutation 1 (Unpermuted data)
# Starting permutation 2
# Starting permutation 3
# Starting permutation 4
# Starting permutation 5
# Starting permutation 6
# Starting permutation 7
# Starting permutation 8
# Starting permutation 9
# Starting permutation 10
# Starting permutation 11
# Starting permutation 12
# Starting permutation 13
# Starting permutation 14
# Starting permutation 15
# Starting permutation 16
# Starting permutation 17
# Starting permutation 18
# Starting permutation 19
# Starting permutation 20
# Starting permutation 21
# Starting permutation 22
# Starting permutation 23
# Starting permutation 24
# Starting permutation 25
# Starting permutation 26
# Starting permutation 27
# Starting permutation 28
# Starting permutation 29
# Starting permutation 30
# Starting permutation 31
# Starting permutation 32
# Starting permutation 33
# Starting permutation 34
# Starting permutation 35
# Starting permutation 36
# Starting permutation 37
# Starting permutation 38
# Starting permutation 39
# Starting permutation 40
# Starting permutation 41
# Starting permutation 42
# Starting permutation 43
# Starting permutation 44
# Starting permutation 45
# Starting permutation 46
# Starting permutation 47
# Starting permutation 48
# Starting permutation 49
# Starting permutation 50
# Starting permutation 51
# Starting permutation 52
# Starting permutation 53
# Starting permutation 54
# Starting permutation 55
# Starting permutation 56
# Starting permutation 57
# Starting permutation 58
# Starting permutation 59
# Starting permutation 60
# Starting permutation 61
# Starting permutation 62
# Starting permutation 63
# Starting permutation 64
# Starting permutation 65
# Starting permutation 66
# Starting permutation 67
# Starting permutation 68
# Starting permutation 69
# Starting permutation 70
# Starting permutation 71
# Starting permutation 72
# Starting permutation 73
# Starting permutation 74
# Starting permutation 75
# Starting permutation 76
# Starting permutation 77
# Starting permutation 78
# Starting permutation 79
# Starting permutation 80
# Starting permutation 81
# Starting permutation 82
# Starting permutation 83
# Starting permutation 84
# Starting permutation 85
# Starting permutation 86
# Starting permutation 87
# Starting permutation 88
# Starting permutation 89
# Starting permutation 90
# Starting permutation 91
# Starting permutation 92
# Starting permutation 93
# Starting permutation 94
# Starting permutation 95
# Starting permutation 96
# Starting permutation 97
# Starting permutation 98
# Starting permutation 99
# Starting permutation 100
# Starting permutation 101
# Starting permutation 102
# Starting permutation 103
# Starting permutation 104
# Starting permutation 105
# Starting permutation 106
# Starting permutation 107
# Starting permutation 108
# Starting permutation 109
# Starting permutation 110
# Starting permutation 111
# Starting permutation 112
# Starting permutation 113
# Starting permutation 114
# Starting permutation 115
# Starting permutation 116
# Starting permutation 117
# Starting permutation 118
# Starting permutation 119
# Starting permutation 120
# Starting permutation 121
# Starting permutation 122
# Starting permutation 123
# Starting permutation 124
# Starting permutation 125
# Starting permutation 126
# Starting permutation 127
# Starting permutation 128
# Starting permutation 129
# Starting permutation 130
# Starting permutation 131
# Starting permutation 132
# Starting permutation 133
# Starting permutation 134
# Starting permutation 135
# Starting permutation 136
# Starting permutation 137
# Starting permutation 138
# Starting permutation 139
# Starting permutation 140
# Starting permutation 141
# Starting permutation 142
# Starting permutation 143
# Starting permutation 144
# Starting permutation 145
# Starting permutation 146
# Starting permutation 147
# Starting permutation 148
# Starting permutation 149
# Starting permutation 150
# Starting permutation 151
# Starting permutation 152
# Starting permutation 153
# Starting permutation 154
# Starting permutation 155
# Starting permutation 156
# Starting permutation 157
# Starting permutation 158
# Starting permutation 159
# Starting permutation 160
# Starting permutation 161
# Starting permutation 162
# Starting permutation 163
# Starting permutation 164
# Starting permutation 165
# Starting permutation 166
# Starting permutation 167
# Starting permutation 168
# Starting permutation 169
# Starting permutation 170
# Starting permutation 171
# Starting permutation 172
# Starting permutation 173
# Starting permutation 174
# Starting permutation 175
# Starting permutation 176
# Starting permutation 177
# Starting permutation 178
# Starting permutation 179
# Starting permutation 180
# Starting permutation 181
# Starting permutation 182
# Starting permutation 183
# Starting permutation 184
# Starting permutation 185
# Starting permutation 186
# Starting permutation 187
# Starting permutation 188
# Starting permutation 189
# Starting permutation 190
# Starting permutation 191
# Starting permutation 192
# Starting permutation 193
# Starting permutation 194
# Starting permutation 195
# Starting permutation 196
# Starting permutation 197
# Starting permutation 198
# Starting permutation 199
# Starting permutation 200
# Starting permutation 201
# Starting permutation 202
# Starting permutation 203
# Starting permutation 204
# Starting permutation 205
# Starting permutation 206
# Starting permutation 207
# Starting permutation 208
# Starting permutation 209
# Starting permutation 210
# Starting permutation 211
# Starting permutation 212
# Starting permutation 213
# Starting permutation 214
# Starting permutation 215
# Starting permutation 216
# Starting permutation 217
# Starting permutation 218
# Starting permutation 219
# Starting permutation 220
# Starting permutation 221
# Starting permutation 222
# Starting permutation 223
# Starting permutation 224
# Starting permutation 225
# Starting permutation 226
# Starting permutation 227
# Starting permutation 228
# Starting permutation 229
# Starting permutation 230
# Starting permutation 231
# Starting permutation 232
# Starting permutation 233
# Starting permutation 234
# Starting permutation 235
# Starting permutation 236
# Starting permutation 237
# Starting permutation 238
# Starting permutation 239
# Starting permutation 240
# Starting permutation 241
# Starting permutation 242
# Starting permutation 243
# Starting permutation 244
# Starting permutation 245
# Starting permutation 246
# Starting permutation 247
# Starting permutation 248
# Starting permutation 249
# Starting permutation 250
# Starting permutation 251
# Starting permutation 252
# Starting permutation 253
# Starting permutation 254
# Starting permutation 255
# Starting permutation 256
# Starting permutation 257
# Starting permutation 258
# Starting permutation 259
# Starting permutation 260
# Starting permutation 261
# Starting permutation 262
# Starting permutation 263
# Starting permutation 264
# Starting permutation 265
# Starting permutation 266
# Starting permutation 267
# Starting permutation 268
# Starting permutation 269
# Starting permutation 270
# Starting permutation 271
# Starting permutation 272
# Starting permutation 273
# Starting permutation 274
# Starting permutation 275
# Starting permutation 276
# Starting permutation 277
# Starting permutation 278
# Starting permutation 279
# Starting permutation 280
# Starting permutation 281
# Starting permutation 282
# Starting permutation 283
# Starting permutation 284
# Starting permutation 285
# Starting permutation 286
# Starting permutation 287
# Starting permutation 288
# Starting permutation 289
# Starting permutation 290
# Starting permutation 291
# Starting permutation 292
# Starting permutation 293
# Starting permutation 294
# Starting permutation 295
# Starting permutation 296
# Starting permutation 297
# Starting permutation 298
# Starting permutation 299
# Starting permutation 300
# Starting permutation 301
# Starting permutation 302
# Starting permutation 303
# Starting permutation 304
# Starting permutation 305
# Starting permutation 306
# Starting permutation 307
# Starting permutation 308
# Starting permutation 309
# Starting permutation 310
# Starting permutation 311
# Starting permutation 312
# Starting permutation 313
# Starting permutation 314
# Starting permutation 315
# Starting permutation 316
# Starting permutation 317
# Starting permutation 318
# Starting permutation 319
# Starting permutation 320
# Starting permutation 321
# Starting permutation 322
# Starting permutation 323
# Starting permutation 324
# Starting permutation 325
# Starting permutation 326
# Starting permutation 327
# Starting permutation 328
# Starting permutation 329
# Starting permutation 330
# Starting permutation 331
# Starting permutation 332
# Starting permutation 333
# Starting permutation 334
# Starting permutation 335
# Starting permutation 336
# Starting permutation 337
# Starting permutation 338
# Starting permutation 339
# Starting permutation 340
# Starting permutation 341
# Starting permutation 342
# Starting permutation 343
# Starting permutation 344
# Starting permutation 345
# Starting permutation 346
# Starting permutation 347
# Starting permutation 348
# Starting permutation 349
# Starting permutation 350
# Starting permutation 351
# Starting permutation 352
# Starting permutation 353
# Starting permutation 354
# Starting permutation 355
# Starting permutation 356
# Starting permutation 357
# Starting permutation 358
# Starting permutation 359
# Starting permutation 360
# Starting permutation 361
# Starting permutation 362
# Starting permutation 363
# Starting permutation 364
# Starting permutation 365
# Starting permutation 366
# Starting permutation 367
# Starting permutation 368
# Starting permutation 369
# Starting permutation 370
# Starting permutation 371
# Starting permutation 372
# Starting permutation 373
# Starting permutation 374
# Starting permutation 375
# Starting permutation 376
# Starting permutation 377
# Starting permutation 378
# Starting permutation 379
# Starting permutation 380
# Starting permutation 381
# Starting permutation 382
# Starting permutation 383
# Starting permutation 384
# Starting permutation 385
# Starting permutation 386
# Starting permutation 387
# Starting permutation 388
# Starting permutation 389
# Starting permutation 390
# Starting permutation 391
# Starting permutation 392
# Starting permutation 393
# Starting permutation 394
# Starting permutation 395
# Starting permutation 396
# Starting permutation 397
# Starting permutation 398
# Starting permutation 399
# Starting permutation 400
# Starting permutation 401
# Starting permutation 402
# Starting permutation 403
# Starting permutation 404
# Starting permutation 405
# Starting permutation 406
# Starting permutation 407
# Starting permutation 408
# Starting permutation 409
# Starting permutation 410
# Starting permutation 411
# Starting permutation 412
# Starting permutation 413
# Starting permutation 414
# Starting permutation 415
# Starting permutation 416
# Starting permutation 417
# Starting permutation 418
# Starting permutation 419
# Starting permutation 420
# Starting permutation 421
# Starting permutation 422
# Starting permutation 423
# Starting permutation 424
# Starting permutation 425
# Starting permutation 426
# Starting permutation 427
# Starting permutation 428
# Starting permutation 429
# Starting permutation 430
# Starting permutation 431
# Starting permutation 432
# Starting permutation 433
# Starting permutation 434
# Starting permutation 435
# Starting permutation 436
# Starting permutation 437
# Starting permutation 438
# Starting permutation 439
# Starting permutation 440
# Starting permutation 441
# Starting permutation 442
# Starting permutation 443
# Starting permutation 444
# Starting permutation 445
# Starting permutation 446
# Starting permutation 447
# Starting permutation 448
# Starting permutation 449
# Starting permutation 450
# Starting permutation 451
# Starting permutation 452
# Starting permutation 453
# Starting permutation 454
# Starting permutation 455
# Starting permutation 456
# Starting permutation 457
# Starting permutation 458
# Starting permutation 459
# Starting permutation 460
# Starting permutation 461
# Starting permutation 462
# Starting permutation 463
# Starting permutation 464
# Starting permutation 465
# Starting permutation 466
# Starting permutation 467
# Starting permutation 468
# Starting permutation 469
# Starting permutation 470
# Starting permutation 471
# Starting permutation 472
# Starting permutation 473
# Starting permutation 474
# Starting permutation 475
# Starting permutation 476
# Starting permutation 477
# Starting permutation 478
# Starting permutation 479
# Starting permutation 480
# Starting permutation 481
# Starting permutation 482
# Starting permutation 483
# Starting permutation 484
# Starting permutation 485
# Starting permutation 486
# Starting permutation 487
# Starting permutation 488
# Starting permutation 489
# Starting permutation 490
# Starting permutation 491
# Starting permutation 492
# Starting permutation 493
# Starting permutation 494
# Starting permutation 495
# Starting permutation 496
# Starting permutation 497
# Starting permutation 498
# Starting permutation 499
# Starting permutation 500
# Critical Value for: tbss_old_age_alpha_tfce_tstat2 is: 94.2061
# Finished, exiting.

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_young/stats

randomise -i all_FA -o tbss_young_age_alpha -m mean_FA_mask -d design_age_alpha.mat -t design_age_CR.con -n 500 --T2
randomise -i all_FA -o tbss_young_age_IS -m mean_FA_mask -d design_age_IS.mat -t design_age_CR.con -n 500 --T2
randomise -i all_FA -o tbss_young_age_IV -m mean_FA_mask -d design_age_IV.mat -t design_age_CR.con -n 500 --T2
randomise -i all_FA -o tbss_young_age_RA -m mean_FA_mask -d design_age_RA.mat -t design_age_CR.con -n 500 --T2
# Out:
# randomise options: -i all_FA -o tbss_young_age_alpha -m mean_FA_mask -d design_age_alpha.mat -t design_age_CR.con -n 500 --T2
# Loading Data:
# Data loaded
# 3.42094e+55 permutations required for exhaustive test of t-test 1
# Doing 500 random permutations
# Starting permutation 1 (Unpermuted data)
# Starting permutation 2
# Starting permutation 3
# Starting permutation 4
# Starting permutation 5
# Starting permutation 6
# Starting permutation 7
# Starting permutation 8
# Starting permutation 9
# Starting permutation 10
# Starting permutation 11
# Starting permutation 12
# Starting permutation 13
# Starting permutation 14
# Starting permutation 15
# Starting permutation 16
# Starting permutation 17
# Starting permutation 18
# Starting permutation 19
# Starting permutation 20
# Starting permutation 21
# Starting permutation 22
# Starting permutation 23
# Starting permutation 24
# Starting permutation 25
# Starting permutation 26
# Starting permutation 27
# Starting permutation 28
# Starting permutation 29
# Starting permutation 30
# Starting permutation 31
# Starting permutation 32
# Starting permutation 33
# Starting permutation 34
# Starting permutation 35
# Starting permutation 36
# Starting permutation 37
# Starting permutation 38
# Starting permutation 39
# Starting permutation 40
# Starting permutation 41
# Starting permutation 42
# Starting permutation 43
# Starting permutation 44
# Starting permutation 45
# Starting permutation 46
# Starting permutation 47
# Starting permutation 48
# Starting permutation 49
# Starting permutation 50
# Starting permutation 51
# Starting permutation 52
# Starting permutation 53
# Starting permutation 54
# Starting permutation 55
# Starting permutation 56
# Starting permutation 57
# Starting permutation 58
# Starting permutation 59
# Starting permutation 60
# Starting permutation 61
# Starting permutation 62
# Starting permutation 63
# Starting permutation 64
# Starting permutation 65
# Starting permutation 66
# Starting permutation 67
# Starting permutation 68
# Starting permutation 69
# Starting permutation 70
# Starting permutation 71
# Starting permutation 72
# Starting permutation 73
# Starting permutation 74
# Starting permutation 75
# Starting permutation 76
# Starting permutation 77
# Starting permutation 78
# Starting permutation 79
# Starting permutation 80
# Starting permutation 81
# Starting permutation 82
# Starting permutation 83
# Starting permutation 84
# Starting permutation 85
# Starting permutation 86
# Starting permutation 87
# Starting permutation 88
# Starting permutation 89
# Starting permutation 90
# Starting permutation 91
# Starting permutation 92
# Starting permutation 93
# Starting permutation 94
# Starting permutation 95
# Starting permutation 96
# Starting permutation 97
# Starting permutation 98
# Starting permutation 99
# Starting permutation 100
# Starting permutation 101
# Starting permutation 102
# Starting permutation 103
# Starting permutation 104
# Starting permutation 105
# Starting permutation 106
# Starting permutation 107
# Starting permutation 108
# Starting permutation 109
# Starting permutation 110
# Starting permutation 111
# Starting permutation 112
# Starting permutation 113
# Starting permutation 114
# Starting permutation 115
# Starting permutation 116
# Starting permutation 117
# Starting permutation 118
# Starting permutation 119
# Starting permutation 120
# Starting permutation 121
# Starting permutation 122
# Starting permutation 123
# Starting permutation 124
# Starting permutation 125
# Starting permutation 126
# Starting permutation 127
# Starting permutation 128
# Starting permutation 129
# Starting permutation 130
# Starting permutation 131
# Starting permutation 132
# Starting permutation 133
# Starting permutation 134
# Starting permutation 135
# Starting permutation 136
# Starting permutation 137
# Starting permutation 138
# Starting permutation 139
# Starting permutation 140
# Starting permutation 141
# Starting permutation 142
# Starting permutation 143
# Starting permutation 144
# Starting permutation 145
# Starting permutation 146
# Starting permutation 147
# Starting permutation 148
# Starting permutation 149
# Starting permutation 150
# Starting permutation 151
# Starting permutation 152
# Starting permutation 153
# Starting permutation 154
# Starting permutation 155
# Starting permutation 156
# Starting permutation 157
# Starting permutation 158
# Starting permutation 159
# Starting permutation 160
# Starting permutation 161
# Starting permutation 162
# Starting permutation 163
# Starting permutation 164
# Starting permutation 165
# Starting permutation 166
# Starting permutation 167
# Starting permutation 168
# Starting permutation 169
# Starting permutation 170
# Starting permutation 171
# Starting permutation 172
# Starting permutation 173
# Starting permutation 174
# Starting permutation 175
# Starting permutation 176
# Starting permutation 177
# Starting permutation 178
# Starting permutation 179
# Starting permutation 180
# Starting permutation 181
# Starting permutation 182
# Starting permutation 183
# Starting permutation 184
# Starting permutation 185
# Starting permutation 186
# Starting permutation 187
# Starting permutation 188
# Starting permutation 189
# Starting permutation 190
# Starting permutation 191
# Starting permutation 192
# Starting permutation 193
# Starting permutation 194
# Starting permutation 195
# Starting permutation 196
# Starting permutation 197
# Starting permutation 198
# Starting permutation 199
# Starting permutation 200
# Starting permutation 201
# Starting permutation 202
# Starting permutation 203
# Starting permutation 204
# Starting permutation 205
# Starting permutation 206
# Starting permutation 207
# Starting permutation 208
# Starting permutation 209
# Starting permutation 210
# Starting permutation 211
# Starting permutation 212
# Starting permutation 213
# Starting permutation 214
# Starting permutation 215
# Starting permutation 216
# Starting permutation 217
# Starting permutation 218
# Starting permutation 219
# Starting permutation 220
# Starting permutation 221
# Starting permutation 222
# Starting permutation 223
# Starting permutation 224
# Starting permutation 225
# Starting permutation 226
# Starting permutation 227
# Starting permutation 228
# Starting permutation 229
# Starting permutation 230
# Starting permutation 231
# Starting permutation 232
# Starting permutation 233
# Starting permutation 234
# Starting permutation 235
# Starting permutation 236
# Starting permutation 237
# Starting permutation 238
# Starting permutation 239
# Starting permutation 240
# Starting permutation 241
# Starting permutation 242
# Starting permutation 243
# Starting permutation 244
# Starting permutation 245
# Starting permutation 246
# Starting permutation 247
# Starting permutation 248
# Starting permutation 249
# Starting permutation 250
# Starting permutation 251
# Starting permutation 252
# Starting permutation 253
# Starting permutation 254
# Starting permutation 255
# Starting permutation 256
# Starting permutation 257
# Starting permutation 258
# Starting permutation 259
# Starting permutation 260
# Starting permutation 261
# Starting permutation 262
# Starting permutation 263
# Starting permutation 264
# Starting permutation 265
# Starting permutation 266
# Starting permutation 267
# Starting permutation 268
# Starting permutation 269
# Starting permutation 270
# Starting permutation 271
# Starting permutation 272
# Starting permutation 273
# Starting permutation 274
# Starting permutation 275
# Starting permutation 276
# Starting permutation 277
# Starting permutation 278
# Starting permutation 279
# Starting permutation 280
# Starting permutation 281
# Starting permutation 282
# Starting permutation 283
# Starting permutation 284
# Starting permutation 285
# Starting permutation 286
# Starting permutation 287
# Starting permutation 288
# Starting permutation 289
# Starting permutation 290
# Starting permutation 291
# Starting permutation 292
# Starting permutation 293
# Starting permutation 294
# Starting permutation 295
# Starting permutation 296
# Starting permutation 297
# Starting permutation 298
# Starting permutation 299
# Starting permutation 300
# Starting permutation 301
# Starting permutation 302
# Starting permutation 303
# Starting permutation 304
# Starting permutation 305
# Starting permutation 306
# Starting permutation 307
# Starting permutation 308
# Starting permutation 309
# Starting permutation 310
# Starting permutation 311
# Starting permutation 312
# Starting permutation 313
# Starting permutation 314
# Starting permutation 315
# Starting permutation 316
# Starting permutation 317
# Starting permutation 318
# Starting permutation 319
# Starting permutation 320
# Starting permutation 321
# Starting permutation 322
# Starting permutation 323
# Starting permutation 324
# Starting permutation 325
# Starting permutation 326
# Starting permutation 327
# Starting permutation 328
# Starting permutation 329
# Starting permutation 330
# Starting permutation 331
# Starting permutation 332
# Starting permutation 333
# Starting permutation 334
# Starting permutation 335
# Starting permutation 336
# Starting permutation 337
# Starting permutation 338
# Starting permutation 339
# Starting permutation 340
# Starting permutation 341
# Starting permutation 342
# Starting permutation 343
# Starting permutation 344
# Starting permutation 345
# Starting permutation 346
# Starting permutation 347
# Starting permutation 348
# Starting permutation 349
# Starting permutation 350
# Starting permutation 351
# Starting permutation 352
# Starting permutation 353
# Starting permutation 354
# Starting permutation 355
# Starting permutation 356
# Starting permutation 357
# Starting permutation 358
# Starting permutation 359
# Starting permutation 360
# Starting permutation 361
# Starting permutation 362
# Starting permutation 363
# Starting permutation 364
# Starting permutation 365
# Starting permutation 366
# Starting permutation 367
# Starting permutation 368
# Starting permutation 369
# Starting permutation 370
# Starting permutation 371
# Starting permutation 372
# Starting permutation 373
# Starting permutation 374
# Starting permutation 375
# Starting permutation 376
# Starting permutation 377
# Starting permutation 378
# Starting permutation 379
# Starting permutation 380
# Starting permutation 381
# Starting permutation 382
# Starting permutation 383
# Starting permutation 384
# Starting permutation 385
# Starting permutation 386
# Starting permutation 387
# Starting permutation 388
# Starting permutation 389
# Starting permutation 390
# Starting permutation 391
# Starting permutation 392
# Starting permutation 393
# Starting permutation 394
# Starting permutation 395
# Starting permutation 396
# Starting permutation 397
# Starting permutation 398
# Starting permutation 399
# Starting permutation 400
# Starting permutation 401
# Starting permutation 402
# Starting permutation 403
# Starting permutation 404
# Starting permutation 405
# Starting permutation 406
# Starting permutation 407
# Starting permutation 408
# Starting permutation 409
# Starting permutation 410
# Starting permutation 411
# Starting permutation 412
# Starting permutation 413
# Starting permutation 414
# Starting permutation 415
# Starting permutation 416
# Starting permutation 417
# Starting permutation 418
# Starting permutation 419
# Starting permutation 420
# Starting permutation 421
# Starting permutation 422
# Starting permutation 423
# Starting permutation 424
# Starting permutation 425
# Starting permutation 426
# Starting permutation 427
# Starting permutation 428
# Starting permutation 429
# Starting permutation 430
# Starting permutation 431
# Starting permutation 432
# Starting permutation 433
# Starting permutation 434
# Starting permutation 435
# Starting permutation 436
# Starting permutation 437
# Starting permutation 438
# Starting permutation 439
# Starting permutation 440
# Starting permutation 441
# Starting permutation 442
# Starting permutation 443
# Starting permutation 444
# Starting permutation 445
# Starting permutation 446
# Starting permutation 447
# Starting permutation 448
# Starting permutation 449
# Starting permutation 450
# Starting permutation 451
# Starting permutation 452
# Starting permutation 453
# Starting permutation 454
# Starting permutation 455
# Starting permutation 456
# Starting permutation 457
# Starting permutation 458
# Starting permutation 459
# Starting permutation 460
# Starting permutation 461
# Starting permutation 462
# Starting permutation 463
# Starting permutation 464
# Starting permutation 465
# Starting permutation 466
# Starting permutation 467
# Starting permutation 468
# Starting permutation 469
# Starting permutation 470
# Starting permutation 471
# Starting permutation 472
# Starting permutation 473
# Starting permutation 474
# Starting permutation 475
# Starting permutation 476
# Starting permutation 477
# Starting permutation 478
# Starting permutation 479
# Starting permutation 480
# Starting permutation 481
# Starting permutation 482
# Starting permutation 483
# Starting permutation 484
# Starting permutation 485
# Starting permutation 486
# Starting permutation 487
# Starting permutation 488
# Starting permutation 489
# Starting permutation 490
# Starting permutation 491
# Starting permutation 492
# Starting permutation 493
# Starting permutation 494
# Starting permutation 495
# Starting permutation 496
# Starting permutation 497
# Starting permutation 498
# Starting permutation 499
# Starting permutation 500
# Critical Value for: tbss_young_age_alpha_tfce_tstat1 is: 1.77011e+08
# 3.42094e+55 permutations required for exhaustive test of t-test 2
# Doing 500 random permutations
# Starting permutation 1 (Unpermuted data)
# Warning: The unpermuted statistic image for the current image contains no positive values, and cannot be processed with TFCE. A blank output image will be created.
# Starting permutation 2
# Starting permutation 3
# Starting permutation 4
# Starting permutation 5
# Starting permutation 6
# Starting permutation 7
# Starting permutation 8
# Starting permutation 9
# Starting permutation 10
# Starting permutation 11
# Starting permutation 12
# Starting permutation 13
# Starting permutation 14
# Starting permutation 15
# Starting permutation 16
# Starting permutation 17
# Starting permutation 18
# Starting permutation 19
# Starting permutation 20
# Starting permutation 21
# Starting permutation 22
# Starting permutation 23
# Starting permutation 24
# Starting permutation 25
# Starting permutation 26
# Starting permutation 27
# Starting permutation 28
# Starting permutation 29
# Starting permutation 30
# Starting permutation 31
# Starting permutation 32
# Starting permutation 33
# Starting permutation 34
# Starting permutation 35
# Starting permutation 36
# Starting permutation 37
# Starting permutation 38
# Starting permutation 39
# Starting permutation 40
# Starting permutation 41
# Starting permutation 42
# Starting permutation 43
# Starting permutation 44
# Starting permutation 45
# Starting permutation 46
# Starting permutation 47
# Starting permutation 48
# Starting permutation 49
# Starting permutation 50
# Starting permutation 51
# Starting permutation 52
# Starting permutation 53
# Starting permutation 54
# Starting permutation 55
# Starting permutation 56
# Starting permutation 57
# Starting permutation 58
# Starting permutation 59
# Starting permutation 60
# Starting permutation 61
# Starting permutation 62
# Starting permutation 63
# Starting permutation 64
# Starting permutation 65
# Starting permutation 66
# Starting permutation 67
# Starting permutation 68
# Starting permutation 69
# Starting permutation 70
# Starting permutation 71
# Starting permutation 72
# Starting permutation 73
# Starting permutation 74
# Starting permutation 75
# Starting permutation 76
# Starting permutation 77
# Starting permutation 78
# Starting permutation 79
# Starting permutation 80
# Starting permutation 81
# Starting permutation 82
# Starting permutation 83
# Starting permutation 84
# Starting permutation 85
# Starting permutation 86
# Starting permutation 87
# Starting permutation 88
# Starting permutation 89
# Starting permutation 90
# Starting permutation 91
# Starting permutation 92
# Starting permutation 93
# Starting permutation 94
# Starting permutation 95
# Starting permutation 96
# Starting permutation 97
# Starting permutation 98
# Starting permutation 99
# Starting permutation 100
# Starting permutation 101
# Starting permutation 102
# Starting permutation 103
# Starting permutation 104
# Starting permutation 105
# Starting permutation 106
# Starting permutation 107
# Starting permutation 108
# Starting permutation 109
# Starting permutation 110
# Starting permutation 111
# Starting permutation 112
# Starting permutation 113
# Starting permutation 114
# Starting permutation 115
# Starting permutation 116
# Starting permutation 117
# Starting permutation 118
# Starting permutation 119
# Starting permutation 120
# Starting permutation 121
# Starting permutation 122
# Starting permutation 123
# Starting permutation 124
# Starting permutation 125
# Starting permutation 126
# Starting permutation 127
# Starting permutation 128
# Starting permutation 129
# Starting permutation 130
# Starting permutation 131
# Starting permutation 132
# Starting permutation 133
# Starting permutation 134
# Starting permutation 135
# Starting permutation 136
# Starting permutation 137
# Starting permutation 138
# Starting permutation 139
# Starting permutation 140
# Starting permutation 141
# Starting permutation 142
# Starting permutation 143
# Starting permutation 144
# Starting permutation 145
# Starting permutation 146
# Starting permutation 147
# Starting permutation 148
# Starting permutation 149
# Starting permutation 150
# Starting permutation 151
# Starting permutation 152
# Starting permutation 153
# Starting permutation 154
# Starting permutation 155
# Starting permutation 156
# Starting permutation 157
# Starting permutation 158
# Starting permutation 159
# Starting permutation 160
# Starting permutation 161
# Starting permutation 162
# Starting permutation 163
# Starting permutation 164
# Starting permutation 165
# Starting permutation 166
# Starting permutation 167
# Starting permutation 168
# Starting permutation 169
# Starting permutation 170
# Starting permutation 171
# Starting permutation 172
# Starting permutation 173
# Starting permutation 174
# Starting permutation 175
# Starting permutation 176
# Starting permutation 177
# Starting permutation 178
# Starting permutation 179
# Starting permutation 180
# Starting permutation 181
# Starting permutation 182
# Starting permutation 183
# Starting permutation 184
# Starting permutation 185
# Starting permutation 186
# Starting permutation 187
# Starting permutation 188
# Starting permutation 189
# Starting permutation 190
# Starting permutation 191
# Starting permutation 192
# Starting permutation 193
# Starting permutation 194
# Starting permutation 195
# Starting permutation 196
# Starting permutation 197
# Starting permutation 198
# Starting permutation 199
# Starting permutation 200
# Starting permutation 201
# Starting permutation 202
# Starting permutation 203
# Starting permutation 204
# Starting permutation 205
# Starting permutation 206
# Starting permutation 207
# Starting permutation 208
# Starting permutation 209
# Starting permutation 210
# Starting permutation 211
# Starting permutation 212
# Starting permutation 213
# Starting permutation 214
# Starting permutation 215
# Starting permutation 216
# Starting permutation 217
# Starting permutation 218
# Starting permutation 219
# Starting permutation 220
# Starting permutation 221
# Starting permutation 222
# Starting permutation 223
# Starting permutation 224
# Starting permutation 225
# Starting permutation 226
# Starting permutation 227
# Starting permutation 228
# Starting permutation 229
# Starting permutation 230
# Starting permutation 231
# Starting permutation 232
# Starting permutation 233
# Starting permutation 234
# Starting permutation 235
# Starting permutation 236
# Starting permutation 237
# Starting permutation 238
# Starting permutation 239
# Starting permutation 240
# Starting permutation 241
# Starting permutation 242
# Starting permutation 243
# Starting permutation 244
# Starting permutation 245
# Starting permutation 246
# Starting permutation 247
# Starting permutation 248
# Starting permutation 249
# Starting permutation 250
# Starting permutation 251
# Starting permutation 252
# Starting permutation 253
# Starting permutation 254
# Starting permutation 255
# Starting permutation 256
# Starting permutation 257
# Starting permutation 258
# Starting permutation 259
# Starting permutation 260
# Starting permutation 261
# Starting permutation 262
# Starting permutation 263
# Starting permutation 264
# Starting permutation 265
# Starting permutation 266
# Starting permutation 267
# Starting permutation 268
# Starting permutation 269
# Starting permutation 270
# Starting permutation 271
# Starting permutation 272
# Starting permutation 273
# Starting permutation 274
# Starting permutation 275
# Starting permutation 276
# Starting permutation 277
# Starting permutation 278
# Starting permutation 279
# Starting permutation 280
# Starting permutation 281
# Starting permutation 282
# Starting permutation 283
# Starting permutation 284
# Starting permutation 285
# Starting permutation 286
# Starting permutation 287
# Starting permutation 288
# Starting permutation 289
# Starting permutation 290
# Starting permutation 291
# Starting permutation 292
# Starting permutation 293
# Starting permutation 294
# Starting permutation 295
# Starting permutation 296
# Starting permutation 297
# Starting permutation 298
# Starting permutation 299
# Starting permutation 300
# Starting permutation 301
# Starting permutation 302
# Starting permutation 303
# Starting permutation 304
# Starting permutation 305
# Starting permutation 306
# Starting permutation 307
# Starting permutation 308
# Starting permutation 309
# Starting permutation 310
# Starting permutation 311
# Starting permutation 312
# Starting permutation 313
# Starting permutation 314
# Starting permutation 315
# Starting permutation 316
# Starting permutation 317
# Starting permutation 318
# Starting permutation 319
# Starting permutation 320
# Starting permutation 321
# Starting permutation 322
# Starting permutation 323
# Starting permutation 324
# Starting permutation 325
# Starting permutation 326
# Starting permutation 327
# Starting permutation 328
# Starting permutation 329
# Starting permutation 330
# Starting permutation 331
# Starting permutation 332
# Starting permutation 333
# Starting permutation 334
# Starting permutation 335
# Starting permutation 336
# Starting permutation 337
# Starting permutation 338
# Starting permutation 339
# Starting permutation 340
# Starting permutation 341
# Starting permutation 342
# Starting permutation 343
# Starting permutation 344
# Starting permutation 345
# Starting permutation 346
# Starting permutation 347
# Starting permutation 348
# Starting permutation 349
# Starting permutation 350
# Starting permutation 351
# Starting permutation 352
# Starting permutation 353
# Starting permutation 354
# Starting permutation 355
# Starting permutation 356
# Starting permutation 357
# Starting permutation 358
# Starting permutation 359
# Starting permutation 360
# Starting permutation 361
# Starting permutation 362
# Starting permutation 363
# Starting permutation 364
# Starting permutation 365
# Starting permutation 366
# Starting permutation 367
# Starting permutation 368
# Starting permutation 369
# Starting permutation 370
# Starting permutation 371
# Starting permutation 372
# Starting permutation 373
# Starting permutation 374
# Starting permutation 375
# Starting permutation 376
# Starting permutation 377
# Starting permutation 378
# Starting permutation 379
# Starting permutation 380
# Starting permutation 381
# Starting permutation 382
# Starting permutation 383
# Starting permutation 384
# Starting permutation 385
# Starting permutation 386
# Starting permutation 387
# Starting permutation 388
# Starting permutation 389
# Starting permutation 390
# Starting permutation 391
# Starting permutation 392
# Starting permutation 393
# Starting permutation 394
# Starting permutation 395
# Starting permutation 396
# Starting permutation 397
# Starting permutation 398
# Starting permutation 399
# Starting permutation 400
# Starting permutation 401
# Starting permutation 402
# Starting permutation 403
# Starting permutation 404
# Starting permutation 405
# Starting permutation 406
# Starting permutation 407
# Starting permutation 408
# Starting permutation 409
# Starting permutation 410
# Starting permutation 411
# Starting permutation 412
# Starting permutation 413
# Starting permutation 414
# Starting permutation 415
# Starting permutation 416
# Starting permutation 417
# Starting permutation 418
# Starting permutation 419
# Starting permutation 420
# Starting permutation 421
# Starting permutation 422
# Starting permutation 423
# Starting permutation 424
# Starting permutation 425
# Starting permutation 426
# Starting permutation 427
# Starting permutation 428
# Starting permutation 429
# Starting permutation 430
# Starting permutation 431
# Starting permutation 432
# Starting permutation 433
# Starting permutation 434
# Starting permutation 435
# Starting permutation 436
# Starting permutation 437
# Starting permutation 438
# Starting permutation 439
# Starting permutation 440
# Starting permutation 441
# Starting permutation 442
# Starting permutation 443
# Starting permutation 444
# Starting permutation 445
# Starting permutation 446
# Starting permutation 447
# Starting permutation 448
# Starting permutation 449
# Starting permutation 450
# Starting permutation 451
# Starting permutation 452
# Starting permutation 453
# Starting permutation 454
# Starting permutation 455
# Starting permutation 456
# Starting permutation 457
# Starting permutation 458
# Starting permutation 459
# Starting permutation 460
# Starting permutation 461
# Starting permutation 462
# Starting permutation 463
# Starting permutation 464
# Starting permutation 465
# Starting permutation 466
# Starting permutation 467
# Starting permutation 468
# Starting permutation 469
# Starting permutation 470
# Starting permutation 471
# Starting permutation 472
# Starting permutation 473
# Starting permutation 474
# Starting permutation 475
# Starting permutation 476
# Starting permutation 477
# Starting permutation 478
# Starting permutation 479
# Starting permutation 480
# Starting permutation 481
# Starting permutation 482
# Starting permutation 483
# Starting permutation 484
# Starting permutation 485
# Starting permutation 486
# Starting permutation 487
# Starting permutation 488
# Starting permutation 489
# Starting permutation 490
# Starting permutation 491
# Starting permutation 492
# Starting permutation 493
# Starting permutation 494
# Starting permutation 495
# Starting permutation 496
# Starting permutation 497
# Starting permutation 498
# Starting permutation 499
# Starting permutation 500
# Critical Value for: tbss_young_age_alpha_tfce_tstat2 is: 0
# Finished, exiting.

# %% [markdown]
# ## New design matrices

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/stats

randomise -i all_FA -o tbss_oa_IS_0218 -m mean_FA_mask_thr22 -d design_IS_0218.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_oa_IV_0218 -m mean_FA_mask_thr22 -d design_IV_0218.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_oa_RA_0218 -m mean_FA_mask_thr22 -d design_RA_0218.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_oa_alpha_0218 -m mean_FA_mask_thr22 -d design_alpha_0218.mat -t design_CR.con -n 500 --T2 -D

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_young_1/stats

randomise -i all_FA -o tbss_ya_IS_0218 -m mean_FA_mask_thr22 -d design_IS_0218.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_ya_IV_0218 -m mean_FA_mask_thr22 -d design_IV_0218.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_ya_RA_0218 -m mean_FA_mask_thr22 -d design_RA_0218.mat -t design_CR.con -n 500 --T2 -D
randomise -i all_FA -o tbss_ya_alpha_0218 -m mean_FA_mask_thr22 -d design_alpha_0218.mat -t design_CR.con -n 500 --T2 -D

# %% [markdown]
# ### Using non-FA Images in TBSS (from [TBSS User Guide](https://fsl.fmrib.ox.ac.uk/fsl/fslwiki/TBSS/UserGuide))
#
# 1. Run the full TBSS analysis on your FA data.
# 2. Create a new directory called MD (or any other name) in your TBSS analysis directory (the one that contains the existing origdata, FA and stats directories from the FA analysis). Type: ```mkdir MD```
# 3. Copy MD images into this new directory, making sure that they are named exactly the same as the original FA images were (look in origdata to check the original names - and keep them exactly the same, even if they include FA, which can be confusing; e.g. if there is an image origdata/subj005_FA.nii.gz then you need an image MD/subj005_FA.nii.gz and this file should contain the MD data, even though it has FA in the name).
# 4. Now, making sure that you are in your top working TBSS directory (the one that now contains FA, stats and MD subdirectories) and run the tbss_non_FA script, telling it that the alternate data is called L2. This will apply the original nonlinear registration to the MD data, merge all subjects' warped MD data into a 4D file stats/all_MD, project this onto the original mean FA skeleton (using the original FA data to find the projection vectors), resulting in the 4D projected data stats/all_MD_skeletonised. Run: ```tbss_non_FA MD```
#
# You can now run voxelwise stats on the projected 4D data all_MD_skeletonised.

# %% [markdown]
# ### Creating masks
#
# 1. Create masks for corpus callosum regions. The corpus callosum is regions 3, 4, and 5 using the JHU atlas.
# 2. Extract mean FA values from the ROI.

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/roi
fslmaths /usr/local/fsl/data/atlases/JHU/JHU-ICBM-labels-1mm.nii.gz -thr 3 -uthr 5 -bin cc_bin.nii.gz
fslmaths ../stats/mean_FA_mask.nii.gz -mas cc_bin.nii.gz -bin cc_bin_mask.nii.gz

cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old_1/stats
fslmeants -i all_FA.nii.gz -m ../roi/cc_bin_mask.nii.gz -o meants_cc.txt

cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_young_1/stats
fslmeants -i all_FA.nii.gz -m ../roi/cc_bin_mask.nii.gz -o meants_cc.txt

# %%
for roinum in 3 4 5 ; do
   fslmaths /usr/local/fsl/data/atlases/JHU/JHU-ICBM-labels-1mm.nii.gz -thr $roinum -uthr $roinum -bin roimask
   fslmaths roimask -mas mean_FA_mask.nii.gz -bin roimask
   padroi=`$FSLDIR/bin/zeropad $roinum 3`
   fslmeants -i all_MD.nii.gz -m roimask -o meants_MD_roi${padroi}.txt
done

# %% [markdown]
# Run TFCE permutation analyses within the corpus callosum

# %%
cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/stats

randomise -i all_FA -o tbss_old_alph_cc_FA -m cc_bin_mask -d design_age_alpha.mat -t design_within_RA.con -n 500 --T2
randomise -i all_MD -o tbss_old_alph_cc_MD -m cc_bin_mask -d design_age_alpha.mat -t design_within_RA.con -n 500 --T2

cd /Volumes/schnyer/Aging_DecMem/Scan_Data/BIDS/derivatives/tbss_old/stats

randomise -i all_MD -o tbss_young_alph_cc_MD -m cc_bin_mask -d design_age_alpha.mat -t design_within_RA.con -n 500 --T2
#also look at f-statistic?
