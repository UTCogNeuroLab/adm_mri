# %%
import os
import numpy as np
import pandas as pd

from scipy import corrcoef
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree
from sklearn import cluster, metrics
import scipy.io

from nilearn import plotting
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from pathlib import Path
home_dir = str(Path.home())
work_dir = os.path.join(home_dir, 'Box/CogNeuroLab/Aging Decision Making R01')

# %%
from nilearn import datasets
dataset = datasets.fetch_atlas_schaefer_2018(n_rois=400, yeo_networks=7, resolution_mm=2, data_dir=os.path.join(work_dir, 'Analysis/schaefer400'))
atlas_filename = dataset.maps
labels = dataset.labels

print('Atlas ROIs are located in nifti image (4D) at: %s' % atlas_filename)  # 4D data
plotting.plot_roi(atlas_filename)
# Out:
# Atlas ROIs are located in nifti image (4D) at: /Users/megmcmahon/Box/CogNeuroLab/Aging Decision Making R01/Analysis/schaefer400/schaefer_2018/Schaefer2018_400Parcels_7Networks_order_FSLMNI152_2mm.nii.gz

# %%
schaefer_coords = np.loadtxt(os.path.join(work_dir, 'Analysis/schaefer400/Schaefer2018_400Parcels_17Networks_order_FSLMNI152_2mm.Centroid_RAS.csv'), delimiter = ',', skiprows=2, usecols=(2,3,4))
schaefer_coords = tuple(map(tuple, schaefer_coords))
schaefer_coords[:5]

labels_df = pd.DataFrame(labels, columns = ['labels'], dtype=str)
dmn_mask = labels_df.index[labels_df['labels'].str.contains('Default')]
fpn_mask = labels_df.index[labels_df['labels'].str.contains('Cont')]

# %% [markdown]
# ## Executive Function and DMN Connectivity

# %%
fcmat_dmn = scipy.io.loadmat(os.path.join(work_dir, 'Analysis/rest/REST_OA_dmn_cor.mat'), squeeze_me=True)['OA_dmn_cormat']

plt.imshow(fcmat_dmn[:,:,1], interpolation='None', cmap='RdYlBu_r')

# %%
adj = np.loadtxt(os.path.join(work_dir, 'Analysis/adj_fact-int.txt'))
plotting.plot_connectome(adj, np.asarray(schaefer_coords)[dmn_mask], node_size=0)

# %%
edgelist = np.where(np.triu(adj)==1)
edgelist
# Out:
# (array([1, 1, 5, 5, 5]), array([ 5, 13,  7, 35, 59]))

# %%
fcmat_dmn[edgelist[0], edgelist[1], 0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-71950b00fc21> in <module>
# ----> 1 fcmat_dmn[edgelist[0], edgelist[1], 0]
#
# NameError: name 'fcmat_dmn' is not defined

# %%
cor = []

for subject in range(0, np.ma.size(fcmat_dmn, 2)):
    cor.append(fcmat_dmn[edgelist[0], edgelist[1], subject])

cor = np.asarray(cor)

# %%
ef = pd.read_csv(os.path.join(work_dir, 'Analysis/neuropsych/oa_neuropsych_zscores.csv'), usecols=['Executive function']).values

# %%
n_wide = int(np.floor(len(edgelist[0])/2 + 1))
fig, axes = plt.subplots(2, n_wide,figsize=[15,8], sharey=True)
fig.suptitle('Functional Connectivity at Significant Edges in Default Mode Network vs. Executive Function in Older Adults', size=14)

for edge in range(0,len(edgelist[0])):
    if edge < n_wide:
        axes[0, edge].scatter(cor[:,edge], ef)
        axes[0, edge].set_title(' '.join(str(labels[dmn_mask][edgelist[0][edge]]).split('_')[3:5]) + ' , ' + ' '.join(str(labels[dmn_mask][edgelist[1][edge]]).split('_')[3:5]), size=11)
    else:
        axes[1, edge-n_wide].scatter(cor[:,edge], ef)
        axes[1, edge-n_wide].set_title(' '.join(str(labels[dmn_mask][edgelist[0][edge]]).split('_')[3:5]) + ' , ' + ' '.join(str(labels[dmn_mask][edgelist[1][edge]]).split('_')[3:5]), size=11)

fig.delaxes(axes[1][3])

fig.text(0.5, 0.04, 'Functional Connectivity', ha='center', size=14)
fig.text(0.07, 0.5, 'Executive Function', va='center', rotation='vertical', size=14)

# plt.gca().legend(loc='center left', bbox_to_anchor=(1.2, 0.9))
# Out:
# Text(0.07, 0.5, 'Executive Function')

# %%
import statsmodels.api as sm
for edge in range(0,7):
    print('\n \n' + str(labels[dmn_mask][edgelist[0][edge]])[23:] + ' , ' + str(labels[dmn_mask][edgelist[1][edge]])[23:])
    mod = sm.OLS(cor[:,edge], ef)
    res = mod.fit()
    print(res.summary())
# Out:
#
# PFC_3' , PFCm_5'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.442
# Method:                 Least Squares   F-statistic:                     35.81
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           3.86e-07
# Time:                        09:55:48   Log-Likelihood:                -17.508
# No. Observations:                  44   AIC:                             37.02
# Df Residuals:                      43   BIC:                             38.80
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4664      0.078      5.984      0.000       0.309       0.624
# ==============================================================================
# Omnibus:                        2.129   Durbin-Watson:                   1.767
# Prob(Omnibus):                  0.345   Jarque-Bera (JB):                1.765
# Skew:                          -0.347   Prob(JB):                        0.414
# Kurtosis:                       2.306   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# PCC_7' , PFCm_1'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.463
# Model:                            OLS   Adj. R-squared:                  0.451
# Method:                 Least Squares   F-statistic:                     37.10
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           2.70e-07
# Time:                        09:55:48   Log-Likelihood:                -20.479
# No. Observations:                  44   AIC:                             42.96
# Df Residuals:                      43   BIC:                             44.74
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5079      0.083      6.091      0.000       0.340       0.676
# ==============================================================================
# Omnibus:                        0.946   Durbin-Watson:                   1.263
# Prob(Omnibus):                  0.623   Jarque-Bera (JB):                0.970
# Skew:                          -0.223   Prob(JB):                        0.616
# Kurtosis:                       2.426   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# PCC_7' , PFCm_5'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.435
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     33.15
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           8.23e-07
# Time:                        09:55:48   Log-Likelihood:                -19.857
# No. Observations:                  44   AIC:                             41.71
# Df Residuals:                      43   BIC:                             43.50
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4733      0.082      5.757      0.000       0.308       0.639
# ==============================================================================
# Omnibus:                        1.317   Durbin-Watson:                   1.527
# Prob(Omnibus):                  0.518   Jarque-Bera (JB):                0.529
# Skew:                          -0.131   Prob(JB):                        0.768
# Kurtosis:                       3.469   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Par_5' , PFCm_1'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.504
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                     43.72
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           4.71e-08
# Time:                        09:55:48   Log-Likelihood:                -19.208
# No. Observations:                  44   AIC:                             40.42
# Df Residuals:                      43   BIC:                             42.20
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5356      0.081      6.612      0.000       0.372       0.699
# ==============================================================================
# Omnibus:                        0.493   Durbin-Watson:                   1.595
# Prob(Omnibus):                  0.782   Jarque-Bera (JB):                0.637
# Skew:                           0.179   Prob(JB):                        0.727
# Kurtosis:                       2.532   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# PFCm_1' , PFCm_12'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.465
# Model:                            OLS   Adj. R-squared:                  0.453
# Method:                 Least Squares   F-statistic:                     37.43
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           2.46e-07
# Time:                        09:55:48   Log-Likelihood:                -24.920
# No. Observations:                  44   AIC:                             51.84
# Df Residuals:                      43   BIC:                             53.62
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5643      0.092      6.118      0.000       0.378       0.750
# ==============================================================================
# Omnibus:                        1.711   Durbin-Watson:                   1.256
# Prob(Omnibus):                  0.425   Jarque-Bera (JB):                1.609
# Skew:                          -0.438   Prob(JB):                        0.447
# Kurtosis:                       2.669   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# PFCm_1' , PCC_5'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.442
# Model:                            OLS   Adj. R-squared:                  0.429
# Method:                 Least Squares   F-statistic:                     34.04
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           6.36e-07
# Time:                        09:55:48   Log-Likelihood:                -18.153
# No. Observations:                  44   AIC:                             38.31
# Df Residuals:                      43   BIC:                             40.09
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.4615      0.079      5.834      0.000       0.302       0.621
# ==============================================================================
# Omnibus:                        0.427   Durbin-Watson:                   1.305
# Prob(Omnibus):                  0.808   Jarque-Bera (JB):                0.582
# Skew:                           0.172   Prob(JB):                        0.748
# Kurtosis:                       2.553   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# PFCm_2' , PFCm_5'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.434
# Method:                 Least Squares   F-statistic:                     34.70
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):           5.27e-07
# Time:                        09:55:48   Log-Likelihood:                -26.665
# No. Observations:                  44   AIC:                             55.33
# Df Residuals:                      43   BIC:                             57.11
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.5653      0.096      5.891      0.000       0.372       0.759
# ==============================================================================
# Omnibus:                        2.258   Durbin-Watson:                   1.225
# Prob(Omnibus):                  0.323   Jarque-Bera (JB):                1.283
# Skew:                           0.326   Prob(JB):                        0.526
# Kurtosis:                       3.524   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Circadian Measures

# %%
fcmat_wb_cr = scipy.io.loadmat(os.path.join(work_dir, 'Analysis/rest/rest_wb-cr_cor.mat'), squeeze_me=True)['wb_cr_cormat']
fcmat_dmn_cr = scipy.io.loadmat(os.path.join(work_dir, 'Analysis/rest/rest_dmn-cr_cor.mat'), squeeze_me=True)['dmn_cr_cormat']
fcmat_fpn_cr = scipy.io.loadmat(os.path.join(work_dir, 'Analysis/rest/rest_fpn-cr_cor.mat'), squeeze_me=True)['fpn_cr_cormat']

cr = pd.read_csv(os.path.join(work_dir, 'Analysis/cr_data_for_dsnmat.csv'))
IS = pd.read_csv(os.path.join(work_dir, 'Analysis/cr_data_for_dsnmat.csv'), usecols=['IS']).values
RA = pd.read_csv(os.path.join(work_dir, 'Analysis/cr_data_for_dsnmat.csv'), usecols=['RA']).values

# %% [markdown]
# ### Interdaily Stability
#
# **Whole Brain**

# %%
adj = np.loadtxt(os.path.join(work_dir, 'Analysis/rest/nbs_results/adj_IS-wb.txt'))
plotting.plot_connectome(adj, np.asarray(schaefer_coords), node_size=0)

# %%
edgelist = np.where(np.triu(adj)==1)
fcmat_wb_cr[edgelist[0], edgelist[1], 0]
# Out:
# array([ 0.19866593,  0.72547033,  0.58346249, -0.08016062, -0.57253334,
#         0.3396356 , -0.22139942, -0.0379323 , -0.12895976])

# %%
#Get MNI coordinates of significant edges
for edge in range(0,len(edgelist[0])):
    print(schaefer_coords[edgelist[0][edge]])
# Out:
# (-24.0, -96.0, -12.0)
# (-60.0, -2.0, 10.0)
# (-48.0, -16.0, 40.0)
# (-46.0, -30.0, 44.0)
# (-42.0, 38.0, 22.0)
# (-42.0, 38.0, 22.0)
# (-42.0, 38.0, 22.0)
# (-42.0, 38.0, 22.0)
# (-40.0, 8.0, 34.0)
# (-4.0, 6.0, 28.0)
# (-28.0, 56.0, 12.0)
# (-28.0, 56.0, 12.0)
# (-28.0, 56.0, 12.0)
# (-28.0, 56.0, 12.0)
# (-28.0, 56.0, 12.0)
# (-28.0, 56.0, 12.0)
# (-28.0, 56.0, 12.0)
# (-28.0, 56.0, 12.0)
# (-6.0, 44.0, 6.0)
# (-16.0, 68.0, 8.0)
# (-16.0, 68.0, 8.0)
# (-54.0, 20.0, 12.0)
# (-54.0, 20.0, 12.0)
# (-54.0, 20.0, 12.0)
# (40.0, -14.0, -32.0)
# (40.0, -14.0, -32.0)

# %%
cor = []

for subject in range(0, np.ma.size(fcmat_wb_cr, 2)):
    cor.append(fcmat_wb_cr[edgelist[0], edgelist[1], subject])

cor = np.asarray(cor)

# %%
n_wide = int(np.floor(len(edgelist[0])/2 + 1))
fig, axes = plt.subplots(2, n_wide,figsize=[15,8], sharey=True)
fig.suptitle('Functional Connectivity at Significant Edges vs. Interdaily Stability', size=14)

for edge in range(0,len(edgelist[0])):
    if edge < n_wide:
        axes[0, edge].scatter(cor[:,edge], cr['IS'].where(cr['record_id'] < 40000).values)
        axes[0, edge].scatter(cor[:,edge], cr['IS'].where(cr['record_id'] > 40000).values)
        axes[0, edge].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)
    else:
        axes[1, edge-n_wide].scatter(cor[:,edge], cr['IS'].where(cr['record_id'] < 40000).values)
        axes[1, edge-n_wide].scatter(cor[:,edge], cr['IS'].where(cr['record_id'] > 40000).values)
        axes[1, edge-n_wide].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)

fig.delaxes(axes[1][4])

fig.text(0.5, 0.04, 'Functional Connectivity', ha='center', size=14)
fig.text(0.07, 0.5, 'Interdaily Stability', va='center', rotation='vertical', size=14)

# plt.gca().legend(loc='center left', bbox_to_anchor=(1.2, 0.9))
# Out:
# Text(0.07, 0.5, 'Interdaily Stability')

# %% [markdown]
# ### Edges associated with IS at whole brain level mainly comprise connections between visual areas and frontal or default mode network areas.

# %%
IS_n = pd.read_csv(os.path.join(work_dir, 'Analysis/cr_data_for_dsnmat.csv'), usecols=['record_id', 'IS'])
ef_n = pd.read_csv(os.path.join(work_dir, 'Analysis/neuropsych/ef_zscores.csv'), usecols=['record_id', 'ef_zscore'])
print(len(ef_n))

#making sure subject numbers are aligned 
ef_n = pd.merge(IS_n, ef_n, on='record_id')
print(len(ef_n))

cor_n = pd.DataFrame(cor)
df = pd.concat((cor_n, ef_n), axis=1)

ef_n = ef_n['ef_zscore'].values

df.index[df['record_id'] > 40000] #is 47, so for YA do [:47] and for OA do [47:]
df[:5]
# Out:
# 92
# 88
#           0         1         2         3         4         5         6  \
# 0  0.198666  0.725470  0.583462 -0.080161 -0.572533  0.339636 -0.221399
# 1  0.531239  0.755226  0.612038  0.317917  0.748479  0.732584  0.102619
# 2  0.372056 -0.088354  0.362255  0.139094  0.653825  0.352416  0.221435
# 3  0.609794  0.273159  0.331008 -0.001615  0.477330  0.528041  0.240295
# 4  0.597801  0.509161  0.389415 -0.185797  0.470485  0.632755  0.518482
#
#           7         8  record_id    IS  ef_zscore
# 0 -0.037932 -0.128960      30004  0.42  -0.836570
# 1  0.364435  0.454289      30008  0.45  -0.769594
# 2  0.428202  0.435280      30009  0.30   0.417524
# 3  0.721933 -0.503076      30012  0.34   1.200696
# 4  0.398717 -0.256763      30015  0.35  -1.281553

# %% [markdown]
# ### No significant relationships between functional connectivity at edges associated with higher interdaily stability at a whole brain level and executive function or memory.

# %%
n_wide = int(np.floor(len(edgelist[0])/2 + 1))
fig, axes = plt.subplots(2, n_wide,figsize=[15,8], sharey=True)
fig.suptitle('Functional Connectivity at Edges Correlated with IS vs. Executive Function', size=14)

for edge in range(0,len(edgelist[0])):
    if edge < n_wide:
        axes[0, edge].scatter(cor[:,edge], ef_n)
        axes[0, edge].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)
    else:
        axes[1, edge-n_wide].scatter(cor[:,edge], ef_n)
        axes[1, edge-n_wide].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)

fig.delaxes(axes[1][4])

fig.text(0.5, 0.04, 'Functional Connectivity', ha='center', size=14)
fig.text(0.07, 0.5, 'Executive Function', va='center', rotation='vertical', size=14)
# Out:
# Text(0.07, 0.5, 'Executive Function')

# %%
import statsmodels.api as sm
for edge in range(0,len(edgelist[0])):
    print('\n \n' + ' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]))
    mod = sm.OLS(cor[:,edge], ef_n)
    res = mod.fit()
    print(res.summary())
# Out:
#
# Vis 27' , Cont PFCl 7'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                  0.001242
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.972
# Time:                        09:55:58   Log-Likelihood:                -53.493
# No. Observations:                  88   AIC:                             109.0
# Df Residuals:                      87   BIC:                             111.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0017      0.049     -0.035      0.972      -0.099       0.096
# ==============================================================================
# Omnibus:                       14.139   Durbin-Watson:                   1.718
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):                5.171
# Skew:                          -0.307   Prob(JB):                       0.0754
# Kurtosis:                       1.983   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Vis 31' , Cont PFCl 3'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.4215
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.518
# Time:                        09:55:58   Log-Likelihood:                -60.542
# No. Observations:                  88   AIC:                             123.1
# Df Residuals:                      87   BIC:                             125.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0344      0.053      0.649      0.518      -0.071       0.140
# ==============================================================================
# Omnibus:                        5.889   Durbin-Watson:                   1.373
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                6.038
# Skew:                          -0.629   Prob(JB):                       0.0489
# Kurtosis:                       2.743   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Vis 31' , Cont PFCl 7'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                   0.08645
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.769
# Time:                        09:55:58   Log-Likelihood:                -57.299
# No. Observations:                  88   AIC:                             116.6
# Df Residuals:                      87   BIC:                             119.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0150      0.051      0.294      0.769      -0.087       0.117
# ==============================================================================
# Omnibus:                        6.422   Durbin-Watson:                   1.402
# Prob(Omnibus):                  0.040   Jarque-Bera (JB):                6.611
# Skew:                          -0.664   Prob(JB):                       0.0367
# Kurtosis:                       2.802   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Vis 31' , Limbic OFC 4'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.05387
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.817
# Time:                        09:55:58   Log-Likelihood:                -43.624
# No. Observations:                  88   AIC:                             89.25
# Df Residuals:                      87   BIC:                             91.73
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0102      0.044      0.232      0.817      -0.077       0.097
# ==============================================================================
# Omnibus:                        3.708   Durbin-Watson:                   1.927
# Prob(Omnibus):                  0.157   Jarque-Bera (JB):                2.215
# Skew:                          -0.150   Prob(JB):                        0.330
# Kurtosis:                       2.283   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 7' , Vis 3'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6748
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.414
# Time:                        09:55:58   Log-Likelihood:                -51.576
# No. Observations:                  88   AIC:                             105.2
# Df Residuals:                      87   BIC:                             107.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0393      0.048      0.821      0.414      -0.056       0.135
# ==============================================================================
# Omnibus:                        4.468   Durbin-Watson:                   1.523
# Prob(Omnibus):                  0.107   Jarque-Bera (JB):                4.467
# Skew:                          -0.540   Prob(JB):                        0.107
# Kurtosis:                       2.772   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 7' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.2845
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.595
# Time:                        09:55:58   Log-Likelihood:                -53.755
# No. Observations:                  88   AIC:                             109.5
# Df Residuals:                      87   BIC:                             112.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0262      0.049     -0.533      0.595      -0.124       0.071
# ==============================================================================
# Omnibus:                        9.560   Durbin-Watson:                   1.252
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               10.471
# Skew:                          -0.828   Prob(JB):                      0.00532
# Kurtosis:                       2.661   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCmp 1' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.052
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.308
# Time:                        09:55:58   Log-Likelihood:                -50.496
# No. Observations:                  88   AIC:                             103.0
# Df Residuals:                      87   BIC:                             105.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0485      0.047     -1.026      0.308      -0.143       0.046
# ==============================================================================
# Omnibus:                        2.527   Durbin-Watson:                   1.408
# Prob(Omnibus):                  0.283   Jarque-Bera (JB):                1.915
# Skew:                          -0.194   Prob(JB):                        0.384
# Kurtosis:                       2.391   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default PFC 10' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.5969
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.442
# Time:                        09:55:58   Log-Likelihood:                -49.517
# No. Observations:                  88   AIC:                             101.0
# Df Residuals:                      87   BIC:                             103.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0361      0.047     -0.773      0.442      -0.129       0.057
# ==============================================================================
# Omnibus:                        3.054   Durbin-Watson:                   1.665
# Prob(Omnibus):                  0.217   Jarque-Bera (JB):                2.822
# Skew:                          -0.360   Prob(JB):                        0.244
# Kurtosis:                       2.500   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default PFC 12' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.259
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.265
# Time:                        09:55:58   Log-Likelihood:                -45.886
# No. Observations:                  88   AIC:                             93.77
# Df Residuals:                      87   BIC:                             96.25
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0504      0.045     -1.122      0.265      -0.140       0.039
# ==============================================================================
# Omnibus:                        8.711   Durbin-Watson:                   1.653
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                3.365
# Skew:                          -0.130   Prob(JB):                        0.186
# Kurtosis:                       2.078   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
IS_n = pd.read_csv(os.path.join(work_dir, 'Analysis/cr_data_for_dsnmat.csv'), usecols=['record_id', 'IS'])
mem = pd.read_csv(os.path.join(work_dir, 'Analysis/neuropsych/oa_neuropsych_zscores.csv'), usecols=['record_id', 'Memory'])
print(len(mem))

#making sure subject numbers are aligned 
cor_n = pd.DataFrame(cor)
IS_cor = pd.concat((IS_n, cor_n), axis=1)
mem = pd.merge(mem, IS_cor, on='record_id')
print(len(mem))

cor_n = mem.drop(['record_id', 'Memory', 'IS'], axis=1).values
print(len(cor_n))
mem_n = mem['Memory'].values
print(len(mem_n))
# Out:
# 44
# 41
# 41
# 41

# %%
import statsmodels.api as sm
for edge in range(0,len(edgelist[0])):
    print('\n \n' + ' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]))
    mod = sm.OLS(cor_n[:,edge], mem_n)
    res = mod.fit()
    print(res.summary())
# Out:
#
# Vis 27' , Cont PFCl 7'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.025
# Method:                 Least Squares   F-statistic:                  0.007648
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.931
# Time:                        09:55:59   Log-Likelihood:                -27.018
# No. Observations:                  41   AIC:                             56.04
# Df Residuals:                      40   BIC:                             57.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0082      0.093      0.087      0.931      -0.180       0.197
# ==============================================================================
# Omnibus:                        5.748   Durbin-Watson:                   1.796
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                2.389
# Skew:                          -0.255   Prob(JB):                        0.303
# Kurtosis:                       1.933   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Vis 31' , Cont PFCl 3'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.173
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.285
# Time:                        09:55:59   Log-Likelihood:                -26.502
# No. Observations:                  41   AIC:                             55.00
# Df Residuals:                      40   BIC:                             56.72
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0998      0.092      1.083      0.285      -0.086       0.286
# ==============================================================================
# Omnibus:                        2.413   Durbin-Watson:                   1.293
# Prob(Omnibus):                  0.299   Jarque-Bera (JB):                2.178
# Skew:                          -0.474   Prob(JB):                        0.337
# Kurtosis:                       2.387   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Vis 31' , Cont PFCl 7'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.3882
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.537
# Time:                        09:55:59   Log-Likelihood:                -26.765
# No. Observations:                  41   AIC:                             55.53
# Df Residuals:                      40   BIC:                             57.24
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0578      0.093      0.623      0.537      -0.130       0.245
# ==============================================================================
# Omnibus:                        3.787   Durbin-Watson:                   1.304
# Prob(Omnibus):                  0.151   Jarque-Bera (JB):                3.399
# Skew:                          -0.699   Prob(JB):                        0.183
# Kurtosis:                       2.809   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Vis 31' , Limbic OFC 4'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.1865
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.668
# Time:                        09:55:59   Log-Likelihood:                -20.305
# No. Observations:                  41   AIC:                             42.61
# Df Residuals:                      40   BIC:                             44.32
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0342      0.079     -0.432      0.668      -0.194       0.126
# ==============================================================================
# Omnibus:                        3.681   Durbin-Watson:                   2.086
# Prob(Omnibus):                  0.159   Jarque-Bera (JB):                1.680
# Skew:                          -0.080   Prob(JB):                        0.432
# Kurtosis:                       2.021   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 7' , Vis 3'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.4501
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.506
# Time:                        09:55:59   Log-Likelihood:                -23.237
# No. Observations:                  41   AIC:                             48.47
# Df Residuals:                      40   BIC:                             50.19
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0571      0.085      0.671      0.506      -0.115       0.229
# ==============================================================================
# Omnibus:                        3.408   Durbin-Watson:                   1.670
# Prob(Omnibus):                  0.182   Jarque-Bera (JB):                2.759
# Skew:                          -0.635   Prob(JB):                        0.252
# Kurtosis:                       3.016   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 7' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.373
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.248
# Time:                        09:55:59   Log-Likelihood:                -23.738
# No. Observations:                  41   AIC:                             49.48
# Df Residuals:                      40   BIC:                             51.19
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.1010      0.086     -1.172      0.248      -0.275       0.073
# ==============================================================================
# Omnibus:                        5.878   Durbin-Watson:                   1.739
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                3.378
# Skew:                          -0.498   Prob(JB):                        0.185
# Kurtosis:                       2.007   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCmp 1' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                    0.1358
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.714
# Time:                        09:55:59   Log-Likelihood:                -23.743
# No. Observations:                  41   AIC:                             49.49
# Df Residuals:                      40   BIC:                             51.20
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0318      0.086      0.369      0.714      -0.142       0.206
# ==============================================================================
# Omnibus:                        0.984   Durbin-Watson:                   1.929
# Prob(Omnibus):                  0.611   Jarque-Bera (JB):                0.847
# Skew:                           0.008   Prob(JB):                        0.655
# Kurtosis:                       2.296   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default PFC 10' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.029
# Model:                            OLS   Adj. R-squared:                  0.004
# Method:                 Least Squares   F-statistic:                     1.183
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.283
# Time:                        09:55:59   Log-Likelihood:                -20.061
# No. Observations:                  41   AIC:                             42.12
# Df Residuals:                      40   BIC:                             43.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0857      0.079     -1.088      0.283      -0.245       0.074
# ==============================================================================
# Omnibus:                        1.894   Durbin-Watson:                   2.266
# Prob(Omnibus):                  0.388   Jarque-Bera (JB):                1.404
# Skew:                          -0.240   Prob(JB):                        0.496
# Kurtosis:                       2.231   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default PFC 12' , Vis 8'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.020
# Method:                 Least Squares   F-statistic:                    0.1963
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.660
# Time:                        09:55:59   Log-Likelihood:                -17.225
# No. Observations:                  41   AIC:                             36.45
# Df Residuals:                      40   BIC:                             38.16
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0326      0.074     -0.443      0.660      -0.181       0.116
# ==============================================================================
# Omnibus:                        1.033   Durbin-Watson:                   2.465
# Prob(Omnibus):                  0.597   Jarque-Bera (JB):                0.971
# Skew:                           0.190   Prob(JB):                        0.615
# Kurtosis:                       2.348   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Default Mode Network**

# %%
adj = np.loadtxt(os.path.join(work_dir, 'Analysis/rest/nbs_results/adj_IS-dmn.txt'))
plotting.plot_connectome(adj, np.asarray(schaefer_coords)[dmn_mask], node_size=0)

# %%
edgelist = np.where(np.triu(adj)==1)
fcmat_dmn_cr[edgelist[0], edgelist[1], 0]
# Out:
# array([ 0.55686511,  0.59223094,  0.53460587, -0.05594413,  0.24952942,
#         0.37911208,  0.27721147,  0.81619696,  0.50557893, -0.26803176,
#         0.63405551,  0.70315057,  0.5112792 ,  0.81415753, -0.05901004,
#         0.58098434, -0.02942596,  0.41968207,  0.13729175,  0.35342099,
#         0.32577106,  0.43795984,  0.5340853 ,  0.23710119,  0.79624984,
#         0.50051149,  0.79783575,  0.74077442, -0.13221747,  0.6879338 ,
#         0.72801821, -0.02941171,  0.90379686,  0.21184216,  0.59388516,
#         0.3882846 , -0.14835872,  0.16335767,  0.34206122, -0.12762384,
#        -0.13354045, -0.36868454, -0.15064793, -0.08503513,  0.0391001 ,
#         0.0531522 ,  0.66921834, -0.65539345,  0.11288199,  0.00598322,
#         0.09101172, -0.18935551,  0.41207485, -0.21184389, -0.39995366,
#         0.49815462, -0.07440211,  0.16939391,  0.12958216,  0.63840992,
#         0.75021788,  0.53626071,  0.49315632])

# %%
cor = []

for subject in range(0, np.ma.size(fcmat_wb_cr, 2)):
    cor.append(fcmat_wb_cr[edgelist[0], edgelist[1], subject])

cor = np.asarray(cor)

# %%
len(edgelist[0])
# Out:
# 63

# %% [markdown]
# ### Relative Amplitude
#
# **Whole Brain**

# %%
adj = np.loadtxt(os.path.join(work_dir, 'Analysis/rest/nbs_results/adj_RA-wb.txt'))
plotting.plot_connectome(adj, np.asarray(schaefer_coords), node_size=0)

# %%
edgelist = np.where(np.triu(adj)==1)
fcmat_wb_cr[edgelist[0], edgelist[1], 0]
# Out:
# array([-0.36673003, -0.11528816, -0.45044064, -0.47698854,  0.00844868,
#         0.29166007, -0.07800096,  0.08878654, -0.23301361,  0.37472235,
#        -0.06399816,  0.20210074,  0.26829164,  0.28720754,  0.45462245,
#         0.49568526, -0.30610464, -0.20960021,  0.12638238, -0.37529958,
#         0.50051149,  0.74758235, -0.21184389,  0.49815462,  0.04418735,
#         0.47472479])

# %%
cor = []

for subject in range(0, np.ma.size(fcmat_wb_cr, 2)):
    cor.append(fcmat_wb_cr[edgelist[0], edgelist[1], subject])

cor = np.asarray(cor)

# %%
len(edgelist[0])
# Out:
# 26

# %%
n_wide = 6
fig, axes = plt.subplots(5, n_wide,figsize=[20,22], sharey=True)
fig.suptitle('Functional Connectivity at Significant Edges vs. Relative Amplitude', size=14)

for edge in range(0,len(edgelist[0])):
    if edge < n_wide:
        axes[0, edge].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] < 40000).values)
        axes[0, edge].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] > 40000).values)
        axes[0, edge].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)
    elif ((edge >= n_wide) & (edge < n_wide*2)):
        axes[1, edge-n_wide].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] < 40000).values)
        axes[1, edge-n_wide].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] > 40000).values)
        axes[1, edge-n_wide].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)
    elif ((edge >= n_wide*2) & (edge < n_wide*3)):
        axes[2, edge-n_wide*2].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] < 40000).values)
        axes[2, edge-n_wide*2].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] > 40000).values)
        axes[2, edge-n_wide*2].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)
    elif ((edge >= n_wide*3) & (edge < n_wide*4)):
        axes[3, edge-n_wide*3].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] < 40000).values)
        axes[3, edge-n_wide*3].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] > 40000).values)
        axes[3, edge-n_wide*3].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)
    else:
        axes[4, edge-n_wide*4].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] < 40000).values)
        axes[4, edge-n_wide*4].scatter(cor[:,edge], cr['RA'].where(cr['record_id'] > 40000).values)
        axes[4, edge-n_wide*4].set_title(' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]), size=11)

        
fig.delaxes(axes[4][2])
fig.delaxes(axes[4][3])
fig.delaxes(axes[4][4])
fig.delaxes(axes[4][5])

fig.text(0.5, 0.08, 'Functional Connectivity', ha='center', size=14)
fig.text(0.08, 0.5, 'Relative Amplitude', va='center', rotation='vertical', size=14)
# Out:
# Text(0.08, 0.5, 'Relative Amplitude')

# %%
RA_n = pd.read_csv(os.path.join(work_dir, 'Analysis/cr_data_for_dsnmat.csv'), usecols=['record_id', 'RA'])
ef_n = pd.read_csv(os.path.join(work_dir, 'Analysis/neuropsych/ef_zscores.csv'), usecols=['record_id', 'ef_zscore'])
print(len(ef_n))

#making sure subject numbers are aligned 
ef_n = pd.merge(RA_n, ef_n, on='record_id')
print(len(ef_n))

ef_n = ef_n['ef_zscore'].values
# Out:
# 92
# 88

# %%
import statsmodels.api as sm
for edge in range(0,len(edgelist[0])):
    print('\n \n' + ' '.join(str(labels[edgelist[0][edge]]).split('_')[2:5]) + ' , ' + ' '.join(str(labels[edgelist[1][edge]]).split('_')[2:5]))
    mod = sm.OLS(cor[:,edge], ef_n)
    res = mod.fit()
    print(res.summary())
# Out:
#
# Vis 5' , Default PFC 22'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9559
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.331
# Time:                        09:56:12   Log-Likelihood:                -46.180
# No. Observations:                  88   AIC:                             94.36
# Df Residuals:                      87   BIC:                             96.84
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0440      0.045     -0.978      0.331      -0.134       0.045
# ==============================================================================
# Omnibus:                        4.650   Durbin-Watson:                   1.809
# Prob(Omnibus):                  0.098   Jarque-Bera (JB):                3.210
# Skew:                          -0.309   Prob(JB):                        0.201
# Kurtosis:                       2.298   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# SomMot 21' , Default PFC 22'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.5995
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.441
# Time:                        09:56:12   Log-Likelihood:                -51.500
# No. Observations:                  88   AIC:                             105.0
# Df Residuals:                      87   BIC:                             107.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0371      0.048      0.774      0.441      -0.058       0.132
# ==============================================================================
# Omnibus:                        2.622   Durbin-Watson:                   1.678
# Prob(Omnibus):                  0.270   Jarque-Bera (JB):                2.558
# Skew:                          -0.360   Prob(JB):                        0.278
# Kurtosis:                       2.576   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# SomMot 28' , Default PFC 22'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.01379
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.907
# Time:                        09:56:12   Log-Likelihood:                -43.510
# No. Observations:                  88   AIC:                             89.02
# Df Residuals:                      87   BIC:                             91.50
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0051      0.044      0.117      0.907      -0.082       0.092
# ==============================================================================
# Omnibus:                        1.905   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.386   Jarque-Bera (JB):                1.599
# Skew:                          -0.181   Prob(JB):                        0.450
# Kurtosis:                       2.447   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# DorsAttn Post 8' , Default PFC 22'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.06842
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.794
# Time:                        09:56:12   Log-Likelihood:                -55.425
# No. Observations:                  88   AIC:                             112.9
# Df Residuals:                      87   BIC:                             115.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0131      0.050     -0.262      0.794      -0.113       0.086
# ==============================================================================
# Omnibus:                       10.479   Durbin-Watson:                   1.759
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):                4.947
# Skew:                          -0.352   Prob(JB):                       0.0843
# Kurtosis:                       2.077   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont Par 3' , Default PFC 12'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                 0.0002883
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.986
# Time:                        09:56:12   Log-Likelihood:                -56.918
# No. Observations:                  88   AIC:                             115.8
# Df Residuals:                      87   BIC:                             118.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0009      0.051      0.017      0.986      -0.100       0.102
# ==============================================================================
# Omnibus:                        4.732   Durbin-Watson:                   1.149
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                4.773
# Skew:                          -0.551   Prob(JB):                       0.0919
# Kurtosis:                       2.706   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont Par 3' , Default PFC 23'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.012
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     1.068
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.304
# Time:                        09:56:12   Log-Likelihood:                -64.437
# No. Observations:                  88   AIC:                             130.9
# Df Residuals:                      87   BIC:                             133.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0573      0.055      1.033      0.304      -0.053       0.167
# ==============================================================================
# Omnibus:                        8.479   Durbin-Watson:                   0.957
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                5.560
# Skew:                          -0.465   Prob(JB):                       0.0620
# Kurtosis:                       2.192   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont Par 3' , Default PCC 9'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                  0.001753
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.967
# Time:                        09:56:12   Log-Likelihood:                -56.997
# No. Observations:                  88   AIC:                             116.0
# Df Residuals:                      87   BIC:                             118.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0021      0.051      0.042      0.967      -0.099       0.103
# ==============================================================================
# Omnibus:                        3.616   Durbin-Watson:                   1.098
# Prob(Omnibus):                  0.164   Jarque-Bera (JB):                3.606
# Skew:                          -0.467   Prob(JB):                        0.165
# Kurtosis:                       2.668   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont Par 3' , Vis 6'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.2193
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.641
# Time:                        09:56:12   Log-Likelihood:                -49.576
# No. Observations:                  88   AIC:                             101.2
# Df Residuals:                      87   BIC:                             103.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0219      0.047      0.468      0.641      -0.071       0.115
# ==============================================================================
# Omnibus:                        4.681   Durbin-Watson:                   1.648
# Prob(Omnibus):                  0.096   Jarque-Bera (JB):                4.629
# Skew:                          -0.521   Prob(JB):                       0.0988
# Kurtosis:                       2.580   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont Par 6' , Default PFC 22'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.1373
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.712
# Time:                        09:56:12   Log-Likelihood:                -56.722
# No. Observations:                  88   AIC:                             115.4
# Df Residuals:                      87   BIC:                             117.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0188      0.051     -0.370      0.712      -0.120       0.082
# ==============================================================================
# Omnibus:                        4.563   Durbin-Watson:                   1.127
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                3.489
# Skew:                          -0.359   Prob(JB):                        0.175
# Kurtosis:                       2.341   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont Temp 1' , Cont PFCl 9'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.1338
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.715
# Time:                        09:56:12   Log-Likelihood:                -56.492
# No. Observations:                  88   AIC:                             115.0
# Df Residuals:                      87   BIC:                             117.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0185      0.051     -0.366      0.715      -0.119       0.082
# ==============================================================================
# Omnibus:                        5.753   Durbin-Watson:                   1.135
# Prob(Omnibus):                  0.056   Jarque-Bera (JB):                5.388
# Skew:                          -0.542   Prob(JB):                       0.0676
# Kurtosis:                       2.455   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , DorsAttn Post 4'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.225
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.271
# Time:                        09:56:12   Log-Likelihood:                -60.103
# No. Observations:                  88   AIC:                             122.2
# Df Residuals:                      87   BIC:                             124.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0584      0.053      1.107      0.271      -0.046       0.163
# ==============================================================================
# Omnibus:                        3.931   Durbin-Watson:                   1.324
# Prob(Omnibus):                  0.140   Jarque-Bera (JB):                3.888
# Skew:                          -0.504   Prob(JB):                        0.143
# Kurtosis:                       2.791   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , SalVentAttn TempOccPar 1'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.08487
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.771
# Time:                        09:56:12   Log-Likelihood:                -54.126
# No. Observations:                  88   AIC:                             110.3
# Df Residuals:                      87   BIC:                             112.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0144      0.049     -0.291      0.771      -0.112       0.084
# ==============================================================================
# Omnibus:                        2.216   Durbin-Watson:                   1.681
# Prob(Omnibus):                  0.330   Jarque-Bera (JB):                2.131
# Skew:                          -0.306   Prob(JB):                        0.345
# Kurtosis:                       2.547   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , Cont PFCl 2'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                  0.007198
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.933
# Time:                        09:56:12   Log-Likelihood:                -52.367
# No. Observations:                  88   AIC:                             106.7
# Df Residuals:                      87   BIC:                             109.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0041      0.048     -0.085      0.933      -0.100       0.092
# ==============================================================================
# Omnibus:                        3.701   Durbin-Watson:                   1.867
# Prob(Omnibus):                  0.157   Jarque-Bera (JB):                2.358
# Skew:                          -0.196   Prob(JB):                        0.308
# Kurtosis:                       2.300   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , Cont PFCl 12'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.2615
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.610
# Time:                        09:56:12   Log-Likelihood:                -66.386
# No. Observations:                  88   AIC:                             134.8
# Df Residuals:                      87   BIC:                             137.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0290      0.057      0.511      0.610      -0.084       0.142
# ==============================================================================
# Omnibus:                        7.685   Durbin-Watson:                   1.387
# Prob(Omnibus):                  0.021   Jarque-Bera (JB):                7.827
# Skew:                          -0.690   Prob(JB):                       0.0200
# Kurtosis:                       2.522   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , Cont PFCl 14'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.02634
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.871
# Time:                        09:56:12   Log-Likelihood:                -62.231
# No. Observations:                  88   AIC:                             126.5
# Df Residuals:                      87   BIC:                             128.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0088      0.054      0.162      0.871      -0.099       0.116
# ==============================================================================
# Omnibus:                        4.732   Durbin-Watson:                   1.445
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                4.217
# Skew:                          -0.455   Prob(JB):                        0.121
# Kurtosis:                       2.431   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , Cont PFCl 15'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.274
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.262
# Time:                        09:56:12   Log-Likelihood:                -67.457
# No. Observations:                  88   AIC:                             136.9
# Df Residuals:                      87   BIC:                             139.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0647      0.057      1.129      0.262      -0.049       0.179
# ==============================================================================
# Omnibus:                       10.196   Durbin-Watson:                   0.926
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.774
# Skew:                          -0.854   Prob(JB):                      0.00458
# Kurtosis:                       3.138   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , Cont pCun 2'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.1846
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.668
# Time:                        09:56:12   Log-Likelihood:                -51.841
# No. Observations:                  88   AIC:                             105.7
# Df Residuals:                      87   BIC:                             108.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0206      0.048     -0.430      0.668      -0.116       0.075
# ==============================================================================
# Omnibus:                        4.770   Durbin-Watson:                   1.747
# Prob(Omnibus):                  0.092   Jarque-Bera (JB):                4.507
# Skew:                          -0.493   Prob(JB):                        0.105
# Kurtosis:                       2.492   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Cont PFCl 9' , Default PFCm 10'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.1203
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.730
# Time:                        09:56:12   Log-Likelihood:                -68.425
# No. Observations:                  88   AIC:                             138.9
# Df Residuals:                      87   BIC:                             141.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0201      0.058     -0.347      0.730      -0.135       0.095
# ==============================================================================
# Omnibus:                        5.251   Durbin-Watson:                   0.909
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                4.933
# Skew:                          -0.516   Prob(JB):                       0.0849
# Kurtosis:                       2.472   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default Temp 16' , Default PFC 22'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.1511
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.698
# Time:                        09:56:12   Log-Likelihood:                -81.003
# No. Observations:                  88   AIC:                             164.0
# Df Residuals:                      87   BIC:                             166.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0260      0.067      0.389      0.698      -0.107       0.159
# ==============================================================================
# Omnibus:                       29.551   Durbin-Watson:                   0.528
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.890
# Skew:                          -1.467   Prob(JB):                     1.08e-10
# Kurtosis:                       4.976   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default Temp 17' , Default PFC 22'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.2338
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.630
# Time:                        09:56:12   Log-Likelihood:                -75.541
# No. Observations:                  88   AIC:                             153.1
# Df Residuals:                      87   BIC:                             155.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0304      0.063      0.484      0.630      -0.095       0.155
# ==============================================================================
# Omnibus:                       23.579   Durbin-Watson:                   0.587
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.704
# Skew:                          -1.234   Prob(JB):                     7.92e-08
# Kurtosis:                       4.683   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default Temp 17' , Default PFC 23'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     1.784
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.185
# Time:                        09:56:12   Log-Likelihood:                -74.528
# No. Observations:                  88   AIC:                             151.1
# Df Residuals:                      87   BIC:                             153.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0830      0.062      1.336      0.185      -0.041       0.207
# ==============================================================================
# Omnibus:                        6.505   Durbin-Watson:                   0.781
# Prob(Omnibus):                  0.039   Jarque-Bera (JB):                6.511
# Skew:                          -0.624   Prob(JB):                       0.0386
# Kurtosis:                       2.535   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default PFC 22' , Cont PFCl 14'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                  0.006243
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.937
# Time:                        09:56:12   Log-Likelihood:                -60.700
# No. Observations:                  88   AIC:                             123.4
# Df Residuals:                      87   BIC:                             125.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0042      0.053     -0.079      0.937      -0.110       0.101
# ==============================================================================
# Omnibus:                        4.434   Durbin-Watson:                   1.228
# Prob(Omnibus):                  0.109   Jarque-Bera (JB):                4.424
# Skew:                          -0.538   Prob(JB):                        0.109
# Kurtosis:                       2.780   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default PFC 22' , Default Par 2'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.1799
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.672
# Time:                        09:56:12   Log-Likelihood:                -61.289
# No. Observations:                  88   AIC:                             124.6
# Df Residuals:                      87   BIC:                             127.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0227      0.053      0.424      0.672      -0.084       0.129
# ==============================================================================
# Omnibus:                        9.813   Durbin-Watson:                   1.245
# Prob(Omnibus):                  0.007   Jarque-Bera (JB):               10.225
# Skew:                          -0.831   Prob(JB):                      0.00602
# Kurtosis:                       3.161   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Default PFC 22' , Default PFCm 12'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                   0.08396
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.773
# Time:                        09:56:12   Log-Likelihood:                -69.479
# No. Observations:                  88   AIC:                             141.0
# Df Residuals:                      87   BIC:                             143.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0170      0.059      0.290      0.773      -0.100       0.134
# ==============================================================================
# Omnibus:                       14.261   Durbin-Watson:                   0.919
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.584
# Skew:                          -0.962   Prob(JB):                     0.000413
# Kurtosis:                       3.740   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Limbic OFC 4' , Cont PFCl 12'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9001
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.345
# Time:                        09:56:12   Log-Likelihood:                -56.832
# No. Observations:                  88   AIC:                             115.7
# Df Residuals:                      87   BIC:                             118.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0482      0.051     -0.949      0.345      -0.149       0.053
# ==============================================================================
# Omnibus:                        4.790   Durbin-Watson:                   1.265
# Prob(Omnibus):                  0.091   Jarque-Bera (JB):                4.819
# Skew:                          -0.545   Prob(JB):                       0.0898
# Kurtosis:                       2.648   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Limbic OFC 4' , Cont PFCl 14'
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.008
# Method:                 Least Squares   F-statistic:                     1.697
# Date:                Tue, 10 Sep 2019   Prob (F-statistic):              0.196
# Time:                        09:56:12   Log-Likelihood:                -60.721
# No. Observations:                  88   AIC:                             123.4
# Df Residuals:                      87   BIC:                             125.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1            -0.0692      0.053     -1.303      0.196      -0.175       0.036
# ==============================================================================
# Omnibus:                        5.520   Durbin-Watson:                   1.078
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                5.355
# Skew:                          -0.552   Prob(JB):                       0.0687
# Kurtosis:                       2.511   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# **Default Mode Network**

# %%
adj = np.loadtxt(os.path.join(work_dir, 'Analysis/rest/nbs_results/adj_RA-dmn.txt'))
plotting.plot_connectome(adj, np.asarray(schaefer_coords)[dmn_mask], node_size=0)

# %%
edgelist = np.where(np.triu(adj)==1)
fcmat_wb_cr[edgelist[0], edgelist[1], 0]
# Out:
# array([ 0.40742645,  0.39197327,  0.16841635,  0.37486295, -0.29810401,
#         0.4064139 , -0.11542814,  0.12651646,  0.01290792,  0.23912067,
#         0.51963987,  0.487822  , -0.30337738,  0.52552524,  0.3327329 ,
#         0.40435813,  0.20146222, -0.00606624,  0.28441758,  0.20914789,
#         0.03847493, -0.50853478,  0.34178418,  0.0778772 ,  0.25362999,
#         0.10787009,  0.45448178, -0.37955153,  0.54407669, -0.64768447,
#         0.28451815,  0.3835633 ,  0.30470792,  0.17282192,  0.68372836,
#         0.55456908, -0.30384179, -0.31560243,  0.63928478,  0.12946775,
#        -0.04362152, -0.07487828,  0.65832161,  0.22600717,  0.5112009 ,
#         0.77414239, -0.49853102,  0.59647972,  0.63291954,  0.58623536,
#         0.01233009, -0.23637349,  0.63074028,  0.58868345,  0.57048745,
#         0.5732964 , -0.33747053, -0.27533831, -0.30122662, -0.60349731,
#        -0.37373089,  0.20915595,  0.17633304, -0.24705948,  0.29298356,
#         0.43039967,  0.3985772 ,  0.19438037,  0.54814216,  0.44809802,
#         0.41643485,  0.34646922, -0.45852118,  0.51577077,  0.64754779,
#        -0.43420769,  0.14829989, -0.21339457,  0.58696151,  0.90835208,
#         0.53416   ,  0.36412481,  0.22632368,  0.65856166,  0.51396936,
#         0.83025853,  0.85239987,  0.51486609,  0.7119239 , -0.08624035,
#         0.29625748,  0.38946183,  0.03177191,  0.48452705,  0.65382187,
#         0.26543845,  0.42515993,  0.44600057,  0.37502124,  0.48312617,
#         0.48902793,  0.131308  ,  0.27590355,  0.06925723,  0.04104382,
#        -0.24744244,  0.37626612,  0.50918446])

# %%
cor = []

for subject in range(0, np.ma.size(fcmat_wb_cr, 2)):
    cor.append(fcmat_wb_cr[edgelist[0], edgelist[1], subject])

cor = np.asarray(cor)

# %%
len(edgelist[0])
# Out:
# 108

# %% [markdown]
# **Frontoparietal Control Network**

# %%
adj = np.loadtxt(os.path.join(work_dir, 'Analysis/rest/nbs_results/adj_RA-fpn.txt'))
plotting.plot_connectome(adj, np.asarray(schaefer_coords)[fpn_mask], node_size=0)

# %%
edgelist = np.where(np.triu(adj)==1)
fcmat_wb_cr[edgelist[0], edgelist[1], 0]
# Out:
# array([-0.42574624,  0.13933803,  0.07756755, -0.38248724, -0.50506504,
#        -0.2671001 , -0.31384061,  0.77113675,  0.29302828,  0.37312383,
#        -0.63569204,  0.22939154,  0.49047041,  0.30660136, -0.30779323,
#         0.18683136,  0.73464553,  0.23709542,  0.30645522,  0.09043132,
#         0.37114645,  0.56570669,  0.57048745,  0.26089655,  0.51276101,
#         0.53936551,  0.23214898,  0.21583865,  0.10657648, -0.5315032 ,
#        -0.03318672, -0.37491986,  0.67047596, -0.13436761,  0.91071437,
#         0.25960211,  0.77584505,  0.48330168,  0.40813241,  0.88034538,
#         0.5081287 ,  0.8126347 ])

# %%
cor = []

for subject in range(0, np.ma.size(fcmat_wb_cr, 2)):
    cor.append(fcmat_wb_cr[edgelist[0], edgelist[1], subject])

cor = np.asarray(cor)

# %%
len(edgelist[0])
# Out:
# 42
