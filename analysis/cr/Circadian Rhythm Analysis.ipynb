# %% [markdown]
# ## Circadian Rhythm Summary by Age Group

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from pathlib import Path
home_dir = str(Path.home())
work_dir = os.path.join(home_dir, 'Box/CogNeuroLab/Aging Decision Making R01')

# %%
cr = pd.read_csv(os.path.join(work_dir, 'Data/CR/circadian_rhythms_2019-09-07.csv'))
cr[:5]
# Out:
#    record_id    IS    IV    RA     L5 L5_starttime     M10 M10_starttime  \
# 0      30003  0.44  0.89  0.91  12.86     00:51:30  266.31      12:19:30
# 1      30004  0.42  0.71  0.89   9.93     00:46:30  164.84      10:17:30
# 2      30008  0.45  0.63  0.90   7.64     02:26:30  145.23      07:57:30
# 3      30009  0.30  1.26  0.90  12.14     01:02:30  240.90      10:30:30
# 4      30012  0.34  1.18  0.94   7.73     01:34:30  245.98      09:26:30
#
#      actamp    actbeta     actphi    actmin  actmesor  actupmesor  \
# 0  1.482320  19.911147  14.332995  0.448208  1.189368    6.138923
# 1  1.558045   6.912068  14.739565  0.111005  0.890028    6.699403
# 2  1.529356  10.066416  15.490810  0.178720  0.943398    7.692192
# 3  1.894820   4.963440  14.628121  0.000000  0.947410    6.539242
# 4  1.669624  10.319613  15.219783  0.220009  1.054822    7.464044
#
#    actdownmesor   actalph  actwidthratio    rsqact         fact     fnlrgact
# 0     22.527067 -0.543335       0.682839  0.376139  4340.279242  3330.660950
# 1     22.779727 -0.509076       0.670014  0.334649  3620.728537  1459.206692
# 2     23.289428 -0.453666       0.649885  0.404814  4896.217494  2354.115659
# 3     22.717001 -0.520012       0.674073  0.381420  4438.786554  1199.634442
# 4     22.975521 -0.443634       0.646312  0.435081  5541.536016  1984.367813

# %%
oa_rest_ids = np.load(os.path.join(work_dir, 'Analysis/REST/REST_oa_list.npy'))
oa_rest_ids = oa_rest_ids.astype(np.int)
oa_rest_ids
# Out:
# array([40160, 40170, 40288, 40351, 40496, 40512, 40515, 40519, 40520,
#        40522, 40524, 40547, 40550, 40564, 40615, 40619, 40623, 40624,
#        40629, 40638, 40649, 40650, 40655, 40656, 40664, 40668, 40672,
#        40685, 40694, 40720, 40728, 40738, 40743, 40750, 40758, 40767,
#        40768, 40769, 40773, 40777, 40778, 40782, 40796, 40803])

# %%
oa_df = cr[cr['record_id'].isin(oa_rest_ids)]
oa_df[:5]
# Out:
#     record_id    IS    IV    RA     L5 L5_starttime     M10 M10_starttime  \
# 54      40160  0.60  0.62  0.95   5.58     02:36:00  231.23      10:04:00
# 55      40170  0.25  0.38  0.96   2.65     23:42:00  117.65      06:35:00
# 56      40288  0.69  0.86  0.97   2.59     00:06:00  172.20      07:48:00
# 57      40351  0.38  0.62  0.94   7.21     00:21:30  243.01      09:41:30
# 59      40496  0.67  0.56  0.89  11.75     22:55:00  198.18      10:19:00
#
#       actamp    actbeta     actphi    actmin  actmesor  actupmesor  \
# 54  2.027264   4.374406  16.244675  0.000000  1.013632    8.841296
# 55  1.089745  12.964754  14.437002  0.066318  0.611191    6.078938
# 56  1.719326   8.604564  14.435157  0.073020  0.932683    6.864824
# 57  1.830074   3.348847  15.552881  0.000000  0.915037    8.218518
# 59  1.881595   4.397035  15.080122  0.099857  1.040654    8.485017
#
#     actdownmesor   actalph  actwidthratio    rsqact         fact     fnlrgact
# 54     23.648055 -0.359192       0.616948  0.531996  8183.077225   950.802638
# 55     22.795066 -0.578866       0.696505  0.205878  1866.297107   574.864044
# 56     22.005490 -0.399628       0.630861  0.484823  6774.607057  2373.632980
# 57     22.887243 -0.342272       0.611197  0.363979  4119.674102   353.432870
# 59     21.675226 -0.155167       0.549592  0.484280  6759.898112   568.923116

# %%
len(oa_df)
# Out:
# 41

# %%
oa_df.describe()
# Out:
#           record_id         IS         IV         RA         L5         M10  \
# count     41.000000  41.000000  41.000000  41.000000  41.000000   41.000000
# mean   40623.097561   0.479756   0.848049   0.846585  13.771220  161.260488
# std      157.958983   0.145971   0.260137   0.138033  13.955579   49.952355
# min    40160.000000   0.110000   0.380000   0.370000   2.180000   89.870000
# 25%    40547.000000   0.400000   0.660000   0.830000   5.020000  117.990000
# 50%    40655.000000   0.490000   0.840000   0.890000   9.370000  163.590000
# 75%    40750.000000   0.570000   1.010000   0.930000  14.590000  187.630000
# max    40803.000000   0.790000   1.660000   0.970000  65.860000  291.280000
#
#           actamp     actbeta     actphi     actmin   actmesor  actupmesor  \
# count  40.000000   40.000000  40.000000  40.000000  40.000000   40.000000
# mean    1.513209   13.446918  14.834625   0.175294   0.931898    7.149766
# std     0.272595   20.982953   1.417172   0.197477   0.174197    1.446065
# min     1.000000    2.470731  10.540381   0.000000   0.611191    2.789320
# 25%     1.365861    4.391378  13.959951   0.021820   0.807728    6.220750
# 50%     1.516482    9.142584  15.088456   0.116843   0.907412    7.191385
# 75%     1.702914   13.196793  15.630120   0.221786   1.031040    8.046181
# max     2.027264  132.499163  18.499886   0.742505   1.315812    9.984571
#
#        actdownmesor    actalph  actwidthratio     rsqact         fact  \
# count     40.000000  40.000000      40.000000  40.000000    40.000000
# mean      22.519484  -0.422263       0.640405   0.364749  4513.665348
# std        1.611249   0.136684       0.048250   0.108836  2126.891556
# min       18.291443  -0.702737       0.532341   0.111685   905.072519
# 25%       21.644581  -0.505620       0.610990   0.304188  3147.881991
# 50%       22.602508  -0.437568       0.644161   0.366011  4155.938175
# 75%       23.511627  -0.341661       0.668737   0.425928  5725.508622
# max       27.015201  -0.101428       0.748039   0.570141  9548.039421
#
#           fnlrgact
# count    40.000000
# mean   1411.137185
# std     994.871509
# min     125.105543
# 25%     552.045204
# 50%    1261.991762
# 75%    2174.353129
# max    3778.972007

# %%
ya_rest_ids = np.load(os.path.join(work_dir, 'Analysis/REST/REST_ya_list.npy'))
ya_rest_ids = ya_rest_ids.astype(np.int)

# %%
ya_df = cr[cr['record_id'].isin(ya_rest_ids)]
ya_df[:5]
# Out:
#    record_id    IS    IV    RA     L5 L5_starttime     M10 M10_starttime  \
# 1      30004  0.42  0.71  0.89   9.93     00:46:30  164.84      10:17:30
# 2      30008  0.45  0.63  0.90   7.64     02:26:30  145.23      07:57:30
# 3      30009  0.30  1.26  0.90  12.14     01:02:30  240.90      10:30:30
# 4      30012  0.34  1.18  0.94   7.73     01:34:30  245.98      09:26:30
# 5      30015  0.35  1.58  0.94   6.05     23:32:30  197.93      10:52:30
#
#      actamp    actbeta     actphi    actmin  actmesor  actupmesor  \
# 1  1.558045   6.912068  14.739565  0.111005  0.890028    6.699403
# 2  1.529356  10.066416  15.490810  0.178720  0.943398    7.692192
# 3  1.894820   4.963440  14.628121  0.000000  0.947410    6.539242
# 4  1.669624  10.319613  15.219783  0.220009  1.054822    7.464044
# 5  1.573995  11.511982  14.087233  0.122235  0.909233    5.909596
#
#    actdownmesor   actalph  actwidthratio    rsqact         fact     fnlrgact
# 1     22.779727 -0.509076       0.670014  0.334649  3620.728537  1459.206692
# 2     23.289428 -0.453666       0.649885  0.404814  4896.217494  2354.115659
# 3     22.717001 -0.520012       0.674073  0.381420  4438.786554  1199.634442
# 4     22.975521 -0.443634       0.646312  0.435081  5541.536016  1984.367813
# 5     22.264871 -0.539718       0.681470  0.410946  5022.121711  2486.421513

# %%
len(ya_df)
# Out:
# 47

# %%
ya_df.describe()
# Out:
#           record_id         IS         IV         RA         L5         M10  \
# count     47.000000  47.000000  47.000000  47.000000  47.000000   47.000000
# mean   30236.553191   0.388085   0.901277   0.839362  14.601702  164.398511
# std      194.165753   0.114182   0.260923   0.151635  14.356839   43.654957
# min    30004.000000   0.030000   0.390000   0.170000   0.000000   61.550000
# 25%    30071.500000   0.320000   0.725000   0.825000   5.970000  133.440000
# 50%    30217.000000   0.420000   0.900000   0.890000   9.930000  158.830000
# 75%    30406.000000   0.450000   1.055000   0.930000  14.755000  186.600000
# max    30588.000000   0.580000   1.580000   1.000000  66.690000  260.140000
#
#           actamp    actbeta     actphi     actmin   actmesor  actupmesor  \
# count  47.000000  47.000000  47.000000  47.000000  47.000000   47.000000
# mean    1.566452   6.797214  16.553119   0.135560   0.918785    8.663576
# std     0.238628   3.312724   1.436710   0.174476   0.147440    1.675056
# min     1.000000   1.343746  13.818398   0.000000   0.500000    5.856726
# 25%     1.436298   4.794290  15.575429   0.000000   0.805044    7.715822
# 50%     1.541540   6.635972  16.595117   0.098511   0.913713    8.472292
# 75%     1.723397   8.241719  17.606364   0.208853   0.962004    9.769374
# max     2.104373  19.151571  19.572871   0.763577   1.286985   12.284547
#
#        actdownmesor    actalph  actwidthratio     rsqact         fact  \
# count     47.000000  47.000000      47.000000  47.000000    47.000000
# mean      24.442662  -0.488719       0.657462   0.335891  3958.312374
# std        1.557240   0.179785       0.061873   0.105724  1807.165167
# min       21.777670  -1.000000       0.448089   0.093536   742.822724
# 25%       23.257994  -0.580878       0.638513   0.269884  2660.984322
# 50%       24.312280  -0.509076       0.667313   0.346522  3792.516996
# 75%       25.296011  -0.441226       0.696782   0.407880  5131.448578
# max       28.509097   0.162362       0.770957   0.521316  7839.870648
#
#           fnlrgact
# count    47.000000
# mean   1230.919673
# std     945.793333
# min   -2112.073417
# 25%     676.491696
# 50%    1336.971061
# 75%    1955.210156
# max    2689.201255

# %%
cr['group'] = np.where(cr['record_id'] < 40000, 'Young Adults', 'Older Adults')

current_palette = sns.set_palette("colorblind")

sns.violinplot(x = cr['group'], y = cr['IS'], hue = cr['group'])
plt.title('Interdailty Stability')
# Out:
# /usr/local/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Interdailty Stability')

# %%
sns.violinplot(x = cr['group'], y = cr['IV'], hue = cr['group'])
plt.title('Intradaily Variability')
# Out:
# Text(0.5, 1.0, 'Intradaily Variability')

# %%
sns.violinplot(x = cr['group'], y = cr['RA'], hue = cr['group'])
plt.title('Relative Amplitude')
# Out:
# Text(0.5, 1.0, 'Relative Amplitude')

# %% [markdown]
# ## Align with FC data

# %%
rest_ids = np.concatenate((ya_rest_ids, oa_rest_ids))
cr_for_dsnmat = pd.concat((ya_df, oa_df))
cr_for_dsnmat[:5]

cr_for_dsnmat.to_csv(os.path.join(work_dir, 'Analysis/cr_data_for_dsnmat.csv'))

# %%
from nilearn import datasets
from nilearn import plotting

dataset = datasets.fetch_atlas_schaefer_2018(n_rois=400, yeo_networks=7, resolution_mm=2, data_dir=os.path.join(work_dir, 'Analysis/schaefer400'))
atlas_filename = dataset.maps
labels = dataset.labels

print('Atlas ROIs are located in nifti image (4D) at: %s' % atlas_filename)  # 4D data
plotting.plot_roi(atlas_filename)
# Out:
# Atlas ROIs are located in nifti image (4D) at: /Users/megmcmahon/Box/CogNeuroLab/Aging Decision Making R01/Analysis/schaefer400/schaefer_2018/Schaefer2018_400Parcels_7Networks_order_FSLMNI152_2mm.nii.gz

# %%
fc_oa = np.load(os.path.join(work_dir, 'Analysis/rest/REST_correlation_matrices_oa.npy'))
fc_ya = np.load(os.path.join(work_dir, 'Analysis/rest/REST_correlation_matrices_ya.npy'))

# %%
np.setdiff1d(rest_ids, cr_for_dsnmat['record_id'].values)
# Out:
# array([30105, 40515, 40624, 40743])

# %%
np.where(oa_rest_ids == np.setdiff1d(rest_ids, cr_for_dsnmat['record_id'].values)[1])
# Out:
# (array([6]),)

# %%
np.where(oa_rest_ids == np.setdiff1d(rest_ids, cr_for_dsnmat['record_id'].values)[2])
# Out:
# (array([17]),)

# %%
np.where(oa_rest_ids == np.setdiff1d(rest_ids, cr_for_dsnmat['record_id'].values)[3])
# Out:
# (array([32]),)

# %%
np.where(ya_rest_ids == np.setdiff1d(rest_ids, cr_for_dsnmat['record_id'].values)[0])
# Out:
# (array([19]),)

# %%
fc_oa.shape
# Out:
# (44, 400, 400)

# %%
plt.imshow(fc_oa[32,:,:])

# %%
fc_oa_n = np.delete(fc_oa, 32, 0) 
fc_oa_n = np.delete(fc_oa_n, 17, 0) 
fc_oa_n = np.delete(fc_oa_n, 6, 0) 
fc_ya_n = np.delete(fc_ya, 19, 0)

# %%
X = fc_oa_n.transpose()
Y = fc_ya_n.transpose()
fc = np.concatenate((Y, X), axis = 2)

# %%
fc.shape
# Out:
# (400, 400, 88)

# %%
import scipy.io
scipy.io.savemat(os.path.join(work_dir, 'Analysis/rest/rest_wb-cr_cor.mat'), mdict = {'wb_cr_cormat': fc})

# %%
labels_df = pd.DataFrame(labels, columns = ['labels'], dtype=str)
dmn_mask = labels_df.index[labels_df['labels'].str.contains('Default')]

print('DMN')
print(fc.shape)
fc_dmn = []
fc_dmn = fc[dmn_mask][:,dmn_mask]
print(fc_dmn.shape)

plt.imshow(fc_dmn[:,:,1], interpolation='None', cmap='RdYlBu_r')
scipy.io.savemat(os.path.join(work_dir, 'Analysis/rest/rest_dmn-cr_cor.mat'), mdict = {'dmn_cr_cormat': fc_dmn})
# Out:
# DMN
# (400, 400, 88)
# (91, 91, 88)

# %%
fpn_mask = labels_df.index[labels_df['labels'].str.contains('Cont')]

print('FPN')
print(fc.shape)
fc_fpn = []
fc_fpn = fc[fpn_mask][:,fpn_mask]
print(fc_fpn.shape)

plt.imshow(fc_fpn[:,:,1], interpolation='None', cmap='RdYlBu_r')
scipy.io.savemat(os.path.join(work_dir, 'Analysis/rest/rest_fpn-cr_cor.mat'), mdict = {'fpn_cr_cormat': fc_fpn})
# Out:
# FPN
# (400, 400, 88)
# (52, 52, 88)

# %%
redcap = pd.read_csv(os.path.join(work_dir, 'Data/AgingDecMem-MegReport_DATA_2019-09-07_1839.csv'), usecols = ['record_id', 'age', 'sex'])
redcap = redcap.dropna()
redcap[:5]
# Out:
#    record_id   age     sex
# 0          3  22.0  female
# 2          4  27.0  Female
# 4          6  34.0    Male
# 6          8  18.0  Female
# 8          9  25.0       F

# %%
redcap = redcap[~ ((redcap['age'] > 30) & (redcap['age'] < 60))]
redcap['record_id'] = np.where((redcap['age'] >= 18) & (redcap['age'] <= 30), '3' + redcap['record_id'].astype(str).str.zfill(4), redcap['record_id'])
redcap['record_id'] = np.where((redcap['age'] >= 60) & (redcap['age'] <= 90), '4' + redcap['record_id'].astype(str).str.zfill(4), redcap['record_id'])
redcap['record_id'] = redcap['record_id'].astype(int)
redcap['sex'] = np.where(((redcap['sex'].astype(str).str[0] == 'F') | (redcap['sex'].astype(str).str[0] =='f')), 1, 0)

# %%
redcap.head()
# Out:
#    record_id   age  sex
# 0      30003  22.0    1
# 2      30004  27.0    1
# 6      30008  18.0    1
# 8      30009  25.0    1
# 10     30010  21.0    1

# %%
redcap.tail()
# Out:
#     record_id   age  sex
# 268     40861  69.0    0
# 270     40876  71.0    1
# 272     40878  71.0    0
# 274     40891  71.0    0
# 276     40895  64.0    0

# %%
dsnmat_IS = pd.merge(redcap[['record_id', 'age', 'sex']], cr_for_dsnmat[['record_id', 'IS']], on='record_id').drop('record_id', axis=1)
dsnmat_IS.insert(0, 'intercept', 1)
dsnmat_IS = np.asarray(dsnmat_IS)

dsnmat_IV = pd.merge(redcap[['record_id', 'age', 'sex']], cr_for_dsnmat[['record_id', 'IV']], on='record_id').drop('record_id', axis=1)
dsnmat_IV.insert(0, 'intercept', 1)
dsnmat_IV = np.asarray(dsnmat_IV)

dsnmat_RA = pd.merge(redcap[['record_id', 'age', 'sex']], cr_for_dsnmat[['record_id', 'RA']], on='record_id').drop('record_id', axis=1)
dsnmat_RA.insert(0, 'intercept', 1)
dsnmat_RA = np.asarray(dsnmat_RA)

# %%
dsnmat_IS[:5]
# Out:
# array([[ 1.  , 27.  ,  1.  ,  0.42],
#        [ 1.  , 18.  ,  1.  ,  0.45],
#        [ 1.  , 25.  ,  1.  ,  0.3 ],
#        [ 1.  , 30.  ,  0.  ,  0.34],
#        [ 1.  , 26.  ,  0.  ,  0.35]])

# %%
import scipy.io

scipy.io.savemat(os.path.join(work_dir, 'Analysis/dsnmat/dsnmat_IS_age_sex'), mdict = {'dsnmat_IS': dsnmat_IS})
scipy.io.savemat(os.path.join(work_dir, 'Analysis/dsnmat/dsnmat_IV_age_sex'), mdict = {'dsnmat_IV': dsnmat_IV})
scipy.io.savemat(os.path.join(work_dir, 'Analysis/dsnmat/dsnmat_RA_age_sex'), mdict = {'dsnmat_RA': dsnmat_RA})
